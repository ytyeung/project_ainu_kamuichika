# %%
import os
from google import genai
from google.genai import types
from dotenv import load_dotenv
from pydantic import BaseModel, Field
import json

import unicodedata
import re

from pydantic import BaseModel, Field

# %%
load_dotenv()
project_name = os.getenv('PROJECT_NAME')

# %% [markdown]
# The story id, from 1 to 13 according to the 13 Ainu Kamuy Yukars translated by Chiri Yukie. The Yukar ID starts at 1. Chiri's Preface is 0.

# %%
start_at = 2
end_at = 13

# %%
class Translation(BaseModel):
    """The updated translation, and the comments for the update"""
    updated_translation: str = Field(description="The updated translation")
    comment: str = Field(description="Comments on the translation update")

# %%
system_instruction_prompt = """You are a professional translator. You know Japanese, English and Chinese. You can translate Japanese into either Chinese or English."""

client = genai.Client(
      vertexai=True,
      project=project_name,
      location="us-central1",
)

model = "gemini-2.0-flash-001"

generate_content_config = types.GenerateContentConfig(
    temperature = 0,
    top_p = 0,
    max_output_tokens = 8192,
    response_mime_type = 'application/json',
    response_schema = Translation,
    safety_settings = [types.SafetySetting(
      category="HARM_CATEGORY_HATE_SPEECH",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_DANGEROUS_CONTENT",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_SEXUALLY_EXPLICIT",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_HARASSMENT",
      threshold="OFF"
    )],
    system_instruction=[types.Part.from_text(text=system_instruction_prompt)],
  )

# %%
reflection_prompt = """You are translating the following Japanese text into Chinese. The original text is a chant sung by god telling his story. You already have an initial Chinese translation.

Here are your tasks:

1. Compare and criticise the Chinese translation based on the Japanese text. 
3. Improve the Chinese translation based on the comparison results.

Keep the original meanings. Display in Traditional Chinese. If a term cannot be translated, keep the original language.

This is the Japanese text.
{japanese_text}

This is the Chinese translation.
{chinese_translation}
"""

# %%
def generate(client: genai.Client,generate_content_config :types.GenerateContentConfig,model :str, /, prompt :str):

    text_full_prompt = text1 = types.Part.from_text(text=f"{prompt}")

    output = ""

    contents = [
      types.Content(
        role="user",
        parts=[
          text_full_prompt
        ]
      )
    ]

    for chunk in client.models.generate_content_stream(
        model = model,
        contents = contents,
        config = generate_content_config,
        ):
        print(chunk.text, end="")
        output += chunk.text

    return output

def get_output_file_name_key(title :str):
    # setup the output file name
    s = title.split()
    md_name_part = s[0]

    name_2nd_part = ""

    for text in s:
        if text.startswith('“'):
            name_2nd_part = text.replace('“', '').replace('”', '')
        
    md_name_part += "_" + name_2nd_part

    return md_name_part

# %%
# Read the markdown template for writing the Chinese translations to Markdown file

#read in the template
with open("templates/iter1_output_md_template", "r", encoding="utf8") as f:
    md_template = f.read()
    md_template = unicodedata.normalize('NFKC', md_template)

# %%
# read the content page of Ainu original text and get the original title
with open("original_Ainu_text/content.txt", "r", encoding="utf8") as f:
    ainu_content = f.read()
    ainu_content = unicodedata.normalize('NFKC', ainu_content)


s=re.split(r'\n\n', ainu_content)
ainu_titles = re.split(r'\n', s[1])

# %%
for song_no in range(start_at, end_at + 1):

    md_name_part = get_output_file_name_key(ainu_titles[song_no - 1])

    with open(f"raw_translations_main_text_json/{song_no}_{md_name_part}.json", "r", encoding="utf8") as f:
        data_dict = json.load(f)

    reflection_prompt_formatted = reflection_prompt.format(japanese_text=data_dict['japanese_translation'],chinese_translation=data_dict['chinese_translation'])

    updated_translation = generate(client,generate_content_config,model,prompt = reflection_prompt_formatted)

    updated_translation_dict = json.loads(updated_translation)
    print(updated_translation_dict['updated_translation'])
    print(updated_translation_dict['comment'])

    data_dict['updated_chinese_translation'] = updated_translation_dict['updated_translation']
    data_dict['update_comment'] = updated_translation_dict['comment']

    md_output = md_template.format(translated_language="Chinese", ainu_title=data_dict['ainu_title'],
                formatted_prompt=reflection_prompt_formatted,
                japanese_title=data_dict['japanese_title'], input_japanese = data_dict['japanese_translation'],
                output= f"{data_dict['updated_chinese_translation']}\n\n{data_dict['update_comment']}")

    with open(f"updated_translations_main_text_iter1/Mono_Chinese_Translation_JSON/{song_no}_{md_name_part}.json", "w", encoding="utf8") as f:
        json.dump(data_dict, f, ensure_ascii=False, indent=4)

    with open(f"updated_translations_main_text_iter1/Mono_Chinese_Translation/{song_no}_{md_name_part}.md", "w", encoding="utf8") as f:
        f.write(md_output)
# Out:
# {
#   "comment": "The original translation is generally accurate, but some phrases can be improved for better flow and nuance in Chinese. The repetition of \"海的恩賜\" feels a bit clunky and can be simplified. The description of the wife's reaction can also be more vivid. The phrase \"霍哦霍伊\" is kept as is, since it is onomatopoeia. The term \"簗\" is kept as is, since it is a technical term. Overall, the updated translation aims for a more natural and impactful reading experience in Traditional Chinese.",
#   "updated_translation": "狐狸自歌的謠曲「托瓦托瓦托」\n\n托瓦托瓦托\n某日，我前往海邊尋找食物。\n石礫中，鏘啦鏘啦；\n木片中，鏘啦鏘啦。\n一邊走一邊看著我的去向，\n只見海邊擱淺了一條鯨魚，\n人們都盛裝打扮，\n歡慶海的恩澤，歡欣鼓舞，\n切肉的人、搬運的人，\n來來往往，絡繹不絕，\n重要的人物們感謝海的恩澤，並向其膜拜，\n磨刀的人等等，黑壓壓一片，佈滿海灘。\n我看到這景象，非常高興。\n「啊，真想快點到那裡，\n哪怕只分到一點也好。」\n心裡這樣想著，一邊叫著「萬歲！萬歲！」\n一邊\n石礫中，鏘啦鏘啦；\n木片中，鏘啦鏘啦。\n走啊走，走到近處一看，\n卻完全出乎我的意料，\n我原以為是鯨魚擱淺，\n其實是海灘上有一處狗的便所，\n堆著一座巨大的糞山，\n我把它當成了鯨魚。\n我原以為人們歡慶海的恩澤，歡欣鼓舞，\n切肉搬運，\n其實是烏鴉們\n啄食糞便，將糞便撥來撥去，\n往那邊飛，往這邊飛。\n我非常生氣。\n「眼光昏花的沒用傢伙，\n眼光昏花的壞傢伙，\n尾巴下面臭烘烘的傢伙，\n尾巴下面腐爛的傢伙，\n屁股裡流出松脂的傢伙，\n屁股裡流出髒水的傢伙，\n究竟是怎麼看東西的啊！」\n之後我又\n石礫中，鏘啦鏘啦；\n木片中，鏘啦鏘啦。\n從海邊跑開，\n看到我的前方\n有一艘船，船上有兩個人互相弔唁。\n「哎呀，發生了什麼突發事件，\n才會做那種事呢？莫非\n是有人連人帶船翻覆了嗎？\n啊，真想快點到更近的地方，\n聽聽人們在說些什麼。」\n我這樣想著，便高聲叫著「霍哦霍伊！」\n石礫中，鏘啦鏘啦；\n木片中，鏘啦鏘啦。\n飛奔過去一看，\n我以為是船的東西，其實是海灘上的\n岩石，我以為是人的東西，\n其實是兩隻巨大的鵜鶘。\n兩隻巨大的鵜鶘伸長脖子又縮回去，\n我卻看成牠們在互相弔唁。\n「眼光昏花的沒用傢伙，\n眼光昏花的壞傢伙，\n尾巴下面臭烘烘的傢伙，\n尾巴下面腐爛的傢伙，\n屁股裡流出松脂的傢伙，\n屁股裡流出髒水的傢伙，\n究竟是怎麼看東西的啊！」\n之後我又\n石礫中，鏘啦鏘啦；\n木片中，鏘啦鏘啦。\n飛也似地溯河而上，\n只見遠遠的河上游，有兩個女人\n站在淺灘上，抱在一起哭泣。\n我看到這景象，大吃一驚。\n「哎呀，發生了什麼不好的事，\n傳來了什麼凶訊，才會哭成那樣？\n啊，真想快點趕到，聽聽人們\n在說些什麼。」\n我這樣想著，\n石礫中，鏘啦鏘啦。\n飛也似地趕過去一看，\n只見河中央有兩座簗，\n兩座簗的木樁被水流衝擊，搖搖晃晃，\n我卻以為是兩個女人低著頭又抬起頭，\n抱在一起哭泣。\n「眼光昏花的沒用傢伙，\n眼光昏花的壞傢伙，\n尾巴下面臭烘烘的傢伙，\n尾巴下面腐爛的傢伙，\n屁股裡流出松脂的傢伙，\n屁股裡流出髒水的傢伙，\n究竟是怎麼看東西的啊！」\n之後我又，溯河而上，\n石礫中，鏘啦鏘啦。\n飛也似地趕回家。\n看到我的前方，\n不知發生了什麼事，\n我的家燃燒了起來，\n升上天空的濃煙，\n宛如堆積的雲朵。看到這景象，我\n大吃一驚，驚訝得幾乎失去意識。\n我用女人的聲音尖叫著\n跳了起來，從對面有人\n大聲叫著「喂！」朝我飛奔而來。\n仔細一看，那是我的妻子，\n她滿臉驚恐，氣喘吁吁地說：\n「老爺，您怎麼了？」\n我再仔細一看，\n看起來像火災，\n其實我的家完好無損地\n佇立在那裡。沒有火，也沒有煙。\n那是我的妻子在舂米，\n當時風很大，吹散了正在簸的粟米的\n糠秕，\n我把它看成了煙。\n我出門尋找食物，卻什麼也沒找到，\n而且，我又大聲叫喊，我的妻子\n被我嚇了一跳，連同簸箕一起\n把正在簸的粟米都扔掉了，\n今晚什麼都沒得吃了。\n我非常生氣，便把自己\n扔到地板底下睡覺了。\n「眼光昏花的沒用傢伙，\n眼光昏花的壞傢伙，\n尾巴下面臭烘烘的傢伙，\n尾巴下面腐爛的傢伙，\n屁股裡流出松脂的傢伙，\n屁股裡流出髒水的傢伙，\n究竟是怎麼看東西的啊！」\n\n狐狸的首領這樣講述著。"
# }狐狸自歌的謠曲「托瓦托瓦托」
#
# 托瓦托瓦托
# 某日，我前往海邊尋找食物。
# 石礫中，鏘啦鏘啦；
# 木片中，鏘啦鏘啦。
# 一邊走一邊看著我的去向，
# 只見海邊擱淺了一條鯨魚，
# 人們都盛裝打扮，
# 歡慶海的恩澤，歡欣鼓舞，
# 切肉的人、搬運的人，
# 來來往往，絡繹不絕，
# 重要的人物們感謝海的恩澤，並向其膜拜，
# 磨刀的人等等，黑壓壓一片，佈滿海灘。
# 我看到這景象，非常高興。
# 「啊，真想快點到那裡，
# 哪怕只分到一點也好。」
# 心裡這樣想著，一邊叫著「萬歲！萬歲！」
# 一邊
# 石礫中，鏘啦鏘啦；
# 木片中，鏘啦鏘啦。
# 走啊走，走到近處一看，
# 卻完全出乎我的意料，
# 我原以為是鯨魚擱淺，
# 其實是海灘上有一處狗的便所，
# 堆著一座巨大的糞山，
# 我把它當成了鯨魚。
# 我原以為人們歡慶海的恩澤，歡欣鼓舞，
# 切肉搬運，
# 其實是烏鴉們
# 啄食糞便，將糞便撥來撥去，
# 往那邊飛，往這邊飛。
# 我非常生氣。
# 「眼光昏花的沒用傢伙，
# 眼光昏花的壞傢伙，
# 尾巴下面臭烘烘的傢伙，
# 尾巴下面腐爛的傢伙，
# 屁股裡流出松脂的傢伙，
# 屁股裡流出髒水的傢伙，
# 究竟是怎麼看東西的啊！」
# 之後我又
# 石礫中，鏘啦鏘啦；
# 木片中，鏘啦鏘啦。
# 從海邊跑開，
# 看到我的前方
# 有一艘船，船上有兩個人互相弔唁。
# 「哎呀，發生了什麼突發事件，
# 才會做那種事呢？莫非
# 是有人連人帶船翻覆了嗎？
# 啊，真想快點到更近的地方，
# 聽聽人們在說些什麼。」
# 我這樣想著，便高聲叫著「霍哦霍伊！」
# 石礫中，鏘啦鏘啦；
# 木片中，鏘啦鏘啦。
# 飛奔過去一看，
# 我以為是船的東西，其實是海灘上的
# 岩石，我以為是人的東西，
# 其實是兩隻巨大的鵜鶘。
# 兩隻巨大的鵜鶘伸長脖子又縮回去，
# 我卻看成牠們在互相弔唁。
# 「眼光昏花的沒用傢伙，
# 眼光昏花的壞傢伙，
# 尾巴下面臭烘烘的傢伙，
# 尾巴下面腐爛的傢伙，
# 屁股裡流出松脂的傢伙，
# 屁股裡流出髒水的傢伙，
# 究竟是怎麼看東西的啊！」
# 之後我又
# 石礫中，鏘啦鏘啦；
# 木片中，鏘啦鏘啦。
# 飛也似地溯河而上，
# 只見遠遠的河上游，有兩個女人
# 站在淺灘上，抱在一起哭泣。
# 我看到這景象，大吃一驚。
# 「哎呀，發生了什麼不好的事，
# 傳來了什麼凶訊，才會哭成那樣？
# 啊，真想快點趕到，聽聽人們
# 在說些什麼。」
# 我這樣想著，
# 石礫中，鏘啦鏘啦。
# 飛也似地趕過去一看，
# 只見河中央有兩座簗，
# 兩座簗的木樁被水流衝擊，搖搖晃晃，
# 我卻以為是兩個女人低著頭又抬起頭，
# 抱在一起哭泣。
# 「眼光昏花的沒用傢伙，
# 眼光昏花的壞傢伙，
# 尾巴下面臭烘烘的傢伙，
# 尾巴下面腐爛的傢伙，
# 屁股裡流出松脂的傢伙，
# 屁股裡流出髒水的傢伙，
# 究竟是怎麼看東西的啊！」
# 之後我又，溯河而上，
# 石礫中，鏘啦鏘啦。
# 飛也似地趕回家。
# 看到我的前方，
# 不知發生了什麼事，
# 我的家燃燒了起來，
# 升上天空的濃煙，
# 宛如堆積的雲朵。看到這景象，我
# 大吃一驚，驚訝得幾乎失去意識。
# 我用女人的聲音尖叫著
# 跳了起來，從對面有人
# 大聲叫著「喂！」朝我飛奔而來。
# 仔細一看，那是我的妻子，
# 她滿臉驚恐，氣喘吁吁地說：
# 「老爺，您怎麼了？」
# 我再仔細一看，
# 看起來像火災，
# 其實我的家完好無損地
# 佇立在那裡。沒有火，也沒有煙。
# 那是我的妻子在舂米，
# 當時風很大，吹散了正在簸的粟米的
# 糠秕，
# 我把它看成了煙。
# 我出門尋找食物，卻什麼也沒找到，
# 而且，我又大聲叫喊，我的妻子
# 被我嚇了一跳，連同簸箕一起
# 把正在簸的粟米都扔掉了，
# 今晚什麼都沒得吃了。
# 我非常生氣，便把自己
# 扔到地板底下睡覺了。
# 「眼光昏花的沒用傢伙，
# 眼光昏花的壞傢伙，
# 尾巴下面臭烘烘的傢伙，
# 尾巴下面腐爛的傢伙，
# 屁股裡流出松脂的傢伙，
# 屁股裡流出髒水的傢伙，
# 究竟是怎麼看東西的啊！」
#
# 狐狸的首領這樣講述著。
# The original translation is generally accurate, but some phrases can be improved for better flow and nuance in Chinese. The repetition of "海的恩賜" feels a bit clunky and can be simplified. The description of the wife's reaction can also be more vivid. The phrase "霍哦霍伊" is kept as is, since it is onomatopoeia. The term "簗" is kept as is, since it is a technical term. Overall, the updated translation aims for a more natural and impactful reading experience in Traditional Chinese.
# {
#   "comment": "1.  **「ハイクンテレケ ハイコシテムトリ」**: This part is kept as is, since it's a chant and doesn't have a direct translation.\n2.  **「私は坐して居りました」**: 「靜靜地坐著」 is acceptable, but 「端坐」 is more formal and fitting for a god.\n3.  **「悪い心がむらむらと出て来ました」**: 「邪惡的念頭蠢蠢欲動」 is good, but 「惡念萌生」 is more concise and literary.\n4.  **「軽い足取りで腰やわらかにかけ出しました」**: 「輕盈地,腰肢柔軟地來回奔跑」 is a bit verbose. 「身輕如燕，腰肢款擺」 is more elegant.\n5.  **「重い調子で木片をポキリポキリと折る様にパーウ,パウと叫び」**: 「用沉重的語調,像折斷木片一樣,啪嗚,啪嗚地叫喊」 is accurate, but can be improved. 「以沉重語調，如折木般，啪嗚、啪嗚地叫喊」 is more concise.\n6.  **「上の海が下になり下の海が上になりました」**: 「上面的海變成了下面,下面的海變成了上面」 is literal. 「上下顛倒，海天翻覆」 is more evocative.\n7.  **「蓬よもぎの小弓と蓬の小矢」**: Keep 「蓬」 as is.\n8.  **「雁皮が燃え縮む様に痛みます」**: 「像雁皮燃燒收縮一樣疼痛」 is accurate. 「如雁皮燃燒般劇痛」 is more concise.\n9.  **「死にざまの見ばのよい死方をしたのですね」**: 「死相也很好看啊」 is acceptable, but 「死狀甚佳」 is more concise and formal.\n10. **「楫」**: Keep 「楫」 as is.",
#   "updated_translation": "狐狸親自吟唱的歌謠\n「Haikunteleke Haikoshitemutori」\n\nHaikunteleke Haikoshitemutori\n在國家的海岬，神明的海岬之上\n我端坐著。\n某天我走到外面一看\n海面風平浪靜，遼闊無垠，在海上\n奧基基穆伊、舒彭拉姆卡和薩馬雲庫爾\n三人乘船出海捕魚，看到這一幕，\n我內心惡念萌生。\n這個海岬，國家的海岬，神明的海岬\n之上，我身輕如燕，腰肢款擺。\n以沉重語調，如折木般，啪嗚、啪嗚地叫喊，\n我怒視著這條河的源頭，召喚暴風的魔力。\n隨之而來的是，從這條河的\n源頭吹來猛烈的風，龍捲風，\n一進入海面，立刻\n這片海域，上下顛倒，海天翻覆。\n奧基基穆伊他們的\n漁船在近海的人的海和遠海的人的海\n交匯之處(海的中央)，遭遇了突如其來的巨變，在波浪間\n旋轉。巨大的浪濤像山一樣\n覆蓋到船上。於是，\n奧基基穆伊、薩馬雲庫爾、舒彭拉姆卡\n聲嘶力竭地划槳。\n這艘小船像飛舞的落葉般被吹走，\n眼看就要傾覆，\n但令人欽佩的是，人們非常有力氣，\n這艘小船在風中\n在波浪上滑行。\n看到這一幕，我內心邪惡的念頭再次蠢蠢欲動。\n我身輕如燕，腰肢款擺，\n以沉重語調，如折木般，啪嗚、啪嗚地叫喊，\n我竭盡全力地聲援暴風的魔力。\n在這樣做的過程中，終於，薩馬雲庫爾\n的手上，手下，都流出了鮮血，\n疲憊地倒下了。\n看到他的樣子，我暗自竊笑。\n然後我又更加賣力地\n身輕如燕，腰肢款擺，\n以沉重語調，如折斷木片一樣叫喊，\n聲援暴風的魔力。\n奧基基穆伊和舒彭拉姆卡兩人\n互相鼓勵，勇敢地划著船，\n但是，突然有一天，舒彭拉姆卡\n的手上，手下，都流出了鮮血，\n疲憊地倒下了，看到這一幕，\n我暗自竊笑。\n然後我又身輕如燕，腰肢款擺地\n跳躍奔跑，用沉重的語調，像折斷堅硬的木片\n一樣叫喊，竭盡全力。\n但是，奧基基穆伊卻沒有絲毫疲憊的樣子。\n他身上披著一件薄薄的衣物，\n划著船，在這過程中，\n他手中的槳折斷了。\n於是，他跳到已經疲憊死去的薩馬雲庫爾身上，\n奪走了他手中的槳，獨自一人\n划著船。\n我看到這一幕，內心固有的邪惡念頭再次蠢蠢欲動。\n用沉重的語調，像折斷堅硬的木片一樣叫喊，\n身輕如燕，腰肢款擺，\n竭盡全力地聲援暴風的魔力。\n在這樣做的過程中，薩馬雲庫爾的舵也\n折斷了。奧基基穆伊跳到舒彭拉姆卡身上，\n奪走了他的楫，\n勇敢地划著船。\n但是他的楫也被海浪折斷了。\n於是，奧基基穆伊在船中\n站立著，在猛烈的風中，\n他萬萬沒想到身為人類的他會發現我，\n他凝視著國家的海岬，神明的海岬\n之上的，我的眼睛中央。\n他原本溫柔的臉上露出了憤怒的神色，\n擺弄著他的袋子，\n從中取出的是，蓬草的小弓和\n蓬草的小箭。\n看到這一幕，我暗自竊笑。\n「人類又能做什麼，有什麼可怕的，\n那種蓬草的小箭有什麼用呢?」\n我這樣想著，在這個海岬\n國家的海岬，神明的海岬之上\n我一直向上，一直向下，身輕如燕\n腰肢款擺，用沉重的語調\n像折斷堅硬的木片一樣，啪嗚、啪嗚地叫喊，\n讚美暴風的魔力。\n在其中，奧基基穆伊射出的箭飛了過來，\n正好刺穿了我的衣領。\n從那以後，我就不知道發生了什麼。\n突然回過神來，\n天氣非常好，海面上\n遼闊無垠，奧基基穆伊的漁船什麼的都不見了。\n怎麼回事，我的頭頂\n到腳尖，都如雁皮燃燒般劇痛。\n萬萬沒想到人類射出的小箭會如此折磨我，於是我掙扎著，\n在這個海岬，國家的海岬，神明的海岬\n之上，一直向上，一直向下，哭喊著\n掙扎，白天黑夜，時而活著，\n時而死去，在這樣的過程中，我不知道\n發生了什麼。\n突然回過神來，\n我身處於一隻巨大的黑狐的耳朵和耳朵之間。\n過了兩天左右，奧基基穆伊像神明一樣\n走了過來，笑眯眯地說道，\n「真是好看啊，守護著國家的海岬，神明的海岬\n之上的黑狐神明，\n因為擁有善良的心，神明的心，\n所以死狀甚佳。」\n說著，他拿走了我的頭，\n帶回了自己的家，把我的上顎骨\n當作自己廁所的地基，把我的下顎\n當作他妻子的廁所的基石，\n我的身體就那樣和泥土一起腐爛了。\n從那以後，無論白天黑夜，\n我都飽受惡臭的折磨，我死得毫無價值，死得很慘。\n我雖然不是地位低微的神明，\n但因為我懷有非常邪惡的心，所以一無是處，\n我死得很慘，\n所以從今以後的狐狸們啊，千萬\n不要懷有邪惡的心。\n\n狐狸神明這樣講述道。"
# }狐狸親自吟唱的歌謠
# 「Haikunteleke Haikoshitemutori」
#
# Haikunteleke Haikoshitemutori
# 在國家的海岬，神明的海岬之上
# 我端坐著。
# 某天我走到外面一看
# 海面風平浪靜，遼闊無垠，在海上
# 奧基基穆伊、舒彭拉姆卡和薩馬雲庫爾
# 三人乘船出海捕魚，看到這一幕，
# 我內心惡念萌生。
# 這個海岬，國家的海岬，神明的海岬
# 之上，我身輕如燕，腰肢款擺。
# 以沉重語調，如折木般，啪嗚、啪嗚地叫喊，
# 我怒視著這條河的源頭，召喚暴風的魔力。
# 隨之而來的是，從這條河的
# 源頭吹來猛烈的風，龍捲風，
# 一進入海面，立刻
# 這片海域，上下顛倒，海天翻覆。
# 奧基基穆伊他們的
# 漁船在近海的人的海和遠海的人的海
# 交匯之處(海的中央)，遭遇了突如其來的巨變，在波浪間
# 旋轉。巨大的浪濤像山一樣
# 覆蓋到船上。於是，
# 奧基基穆伊、薩馬雲庫爾、舒彭拉姆卡
# 聲嘶力竭地划槳。
# 這艘小船像飛舞的落葉般被吹走，
# 眼看就要傾覆，
# 但令人欽佩的是，人們非常有力氣，
# 這艘小船在風中
# 在波浪上滑行。
# 看到這一幕，我內心邪惡的念頭再次蠢蠢欲動。
# 我身輕如燕，腰肢款擺，
# 以沉重語調，如折木般，啪嗚、啪嗚地叫喊，
# 我竭盡全力地聲援暴風的魔力。
# 在這樣做的過程中，終於，薩馬雲庫爾
# 的手上，手下，都流出了鮮血，
# 疲憊地倒下了。
# 看到他的樣子，我暗自竊笑。
# 然後我又更加賣力地
# 身輕如燕，腰肢款擺，
# 以沉重語調，如折斷木片一樣叫喊，
# 聲援暴風的魔力。
# 奧基基穆伊和舒彭拉姆卡兩人
# 互相鼓勵，勇敢地划著船，
# 但是，突然有一天，舒彭拉姆卡
# 的手上，手下，都流出了鮮血，
# 疲憊地倒下了，看到這一幕，
# 我暗自竊笑。
# 然後我又身輕如燕，腰肢款擺地
# 跳躍奔跑，用沉重的語調，像折斷堅硬的木片
# 一樣叫喊，竭盡全力。
# 但是，奧基基穆伊卻沒有絲毫疲憊的樣子。
# 他身上披著一件薄薄的衣物，
# 划著船，在這過程中，
# 他手中的槳折斷了。
# 於是，他跳到已經疲憊死去的薩馬雲庫爾身上，
# 奪走了他手中的槳，獨自一人
# 划著船。
# 我看到這一幕，內心固有的邪惡念頭再次蠢蠢欲動。
# 用沉重的語調，像折斷堅硬的木片一樣叫喊，
# 身輕如燕，腰肢款擺，
# 竭盡全力地聲援暴風的魔力。
# 在這樣做的過程中，薩馬雲庫爾的舵也
# 折斷了。奧基基穆伊跳到舒彭拉姆卡身上，
# 奪走了他的楫，
# 勇敢地划著船。
# 但是他的楫也被海浪折斷了。
# 於是，奧基基穆伊在船中
# 站立著，在猛烈的風中，
# 他萬萬沒想到身為人類的他會發現我，
# 他凝視著國家的海岬，神明的海岬
# 之上的，我的眼睛中央。
# 他原本溫柔的臉上露出了憤怒的神色，
# 擺弄著他的袋子，
# 從中取出的是，蓬草的小弓和
# 蓬草的小箭。
# 看到這一幕，我暗自竊笑。
# 「人類又能做什麼，有什麼可怕的，
# 那種蓬草的小箭有什麼用呢?」
# 我這樣想著，在這個海岬
# 國家的海岬，神明的海岬之上
# 我一直向上，一直向下，身輕如燕
# 腰肢款擺，用沉重的語調
# 像折斷堅硬的木片一樣，啪嗚、啪嗚地叫喊，
# 讚美暴風的魔力。
# 在其中，奧基基穆伊射出的箭飛了過來，
# 正好刺穿了我的衣領。
# 從那以後，我就不知道發生了什麼。
# 突然回過神來，
# 天氣非常好，海面上
# 遼闊無垠，奧基基穆伊的漁船什麼的都不見了。
# 怎麼回事，我的頭頂
# 到腳尖，都如雁皮燃燒般劇痛。
# 萬萬沒想到人類射出的小箭會如此折磨我，於是我掙扎著，
# 在這個海岬，國家的海岬，神明的海岬
# 之上，一直向上，一直向下，哭喊著
# 掙扎，白天黑夜，時而活著，
# 時而死去，在這樣的過程中，我不知道
# 發生了什麼。
# 突然回過神來，
# 我身處於一隻巨大的黑狐的耳朵和耳朵之間。
# 過了兩天左右，奧基基穆伊像神明一樣
# 走了過來，笑眯眯地說道，
# 「真是好看啊，守護著國家的海岬，神明的海岬
# 之上的黑狐神明，
# 因為擁有善良的心，神明的心，
# 所以死狀甚佳。」
# 說著，他拿走了我的頭，
# 帶回了自己的家，把我的上顎骨
# 當作自己廁所的地基，把我的下顎
# 當作他妻子的廁所的基石，
# 我的身體就那樣和泥土一起腐爛了。
# 從那以後，無論白天黑夜，
# 我都飽受惡臭的折磨，我死得毫無價值，死得很慘。
# 我雖然不是地位低微的神明，
# 但因為我懷有非常邪惡的心，所以一無是處，
# 我死得很慘，
# 所以從今以後的狐狸們啊，千萬
# 不要懷有邪惡的心。
#
# 狐狸神明這樣講述道。
# 1.  **「ハイクンテレケ ハイコシテムトリ」**: This part is kept as is, since it's a chant and doesn't have a direct translation.
# 2.  **「私は坐して居りました」**: 「靜靜地坐著」 is acceptable, but 「端坐」 is more formal and fitting for a god.
# 3.  **「悪い心がむらむらと出て来ました」**: 「邪惡的念頭蠢蠢欲動」 is good, but 「惡念萌生」 is more concise and literary.
# 4.  **「軽い足取りで腰やわらかにかけ出しました」**: 「輕盈地,腰肢柔軟地來回奔跑」 is a bit verbose. 「身輕如燕，腰肢款擺」 is more elegant.
# 5.  **「重い調子で木片をポキリポキリと折る様にパーウ,パウと叫び」**: 「用沉重的語調,像折斷木片一樣,啪嗚,啪嗚地叫喊」 is accurate, but can be improved. 「以沉重語調，如折木般，啪嗚、啪嗚地叫喊」 is more concise.
# 6.  **「上の海が下になり下の海が上になりました」**: 「上面的海變成了下面,下面的海變成了上面」 is literal. 「上下顛倒，海天翻覆」 is more evocative.
# 7.  **「蓬よもぎの小弓と蓬の小矢」**: Keep 「蓬」 as is.
# 8.  **「雁皮が燃え縮む様に痛みます」**: 「像雁皮燃燒收縮一樣疼痛」 is accurate. 「如雁皮燃燒般劇痛」 is more concise.
# 9.  **「死にざまの見ばのよい死方をしたのですね」**: 「死相也很好看啊」 is acceptable, but 「死狀甚佳」 is more concise and formal.
# 10. **「楫」**: Keep 「楫」 as is.
# {
#   "comment": "The original translation is generally accurate, but some phrases can be improved for better flow and cultural relevance in Chinese. Some terms are kept in Japanese (Okikirmui) which is good. Here's a breakdown:\n\n*   **桑帕亞 特雷克 (Sanpaya Tereke):** Keep as is.\n*   **弩 (Nu):** Accurate translation, but consider using a more descriptive term like \"弓箭\" (gong jian) for better understanding.\n*   **呼喔呼喔伊 (Hoo hoo i):** Keep as is, as it's a sound effect.\n*   **凱托卡 沃伊沃伊 凱托卡,凱托卡 沃伊 凱托卡 (Ketoka Woivoi Ketoka, Ketoka Woi Ketoka):** Keep as is.\n*   **奧基基里穆伊 (Okikirmui):** Keep as is.\n\nI will focus on improving the flow and naturalness of the Chinese while maintaining accuracy.",
#   "updated_translation": "兔子親自吟唱的歌謠「桑帕亞 特雷克」\n\n桑帕亞 特雷克\n越過兩道山谷，越過三道山谷，\n一邊玩耍，一邊跟隨著哥哥前往山裡。\n每天都跟在哥哥身後，\n看見人類設置了弓箭陷阱，哥哥便將弓箭\n破壞掉。我總是嘲笑他，\n以此為樂。這天又\n去了，卻\n出乎意料地，\n哥哥被弓箭射中，哭喊著。\n我嚇了一跳，飛奔到哥哥身邊，\n哥哥哭著說道：\n「弟弟啊，你現在\n趕快跑回\n我們村子的後方，\n大聲呼喊——哥哥被弓箭射中了，呼喔呼喔伊！」\n我聽了，\n回答說：「好，好。」然後\n越過兩道山谷，越過三道山谷，\n一邊玩耍，一邊來到\n我們村子的後方。\n在那裡才想起哥哥派我來做什麼，\n我正要大聲呼喊，\n卻完全忘記了哥哥要我說什麼。\n我呆立在那裡，\n想要回想起來，卻怎麼也想不起來。\n然後又\n越過兩道山谷，越過三道山谷，\n一邊倒退著跳躍，\n回到哥哥所在的地方，\n卻空無一人。\n只留下哥哥的血跡。\n(到這裡故事轉向別處)\n凱托卡 沃伊沃伊 凱托卡, 凱托卡 沃伊 凱托卡\n每天我都去山裡，\n破壞人類設置的弓箭陷阱，\n並以此為樂。\n有一天，我又來到之前的地方，發現那裡設置了弓箭陷阱，\n而在那旁邊，設置了一個小小的艾草弓箭。\n我看到那個，\n心想：「這種東西，有什麼用呢？」\n覺得很好笑，\n就稍微碰了一下，正要逃跑，\n卻出乎意料地\n被那弓箭緊緊地\n夾住了。\n越是掙扎想要逃脫，\n就夾得越緊，無計可施，\n我哭泣著。\n這時，有什麼東西\n飛到我身邊，一看原來是我的弟弟。\n我很高興，囑咐他將此事告知我們族人，\n但等了許久，卻毫無音訊。\n我哭泣著，這時\n出現了一個身影。一看，\n是一位像神一樣美麗的人類年輕人，\n笑咪咪地，抓住我，\n帶到某個地方。只見\n一個巨大的房子裡，堆滿了神的寶物。\n那位年輕人點燃了火，\n將一個大鍋架在火上，拔出掛著的刀，\n將我的身體連皮帶肉切成碎塊，\n裝滿整個鍋子，然後將頭伸到鍋子底下，\n開始點火燒煮。我想要\n逃脫，便伺機尋找人類年輕人的破綻，\n但人類年輕人卻寸步不離地盯著我。\n「如果鍋子煮沸，我就被煮熟了，那樣就太沒意義了，死得很難看！」\n我這樣想著，伺機尋找人類年輕人的疏忽，\n好不容易\n將自己變成一片肉，\n混入升騰的蒸汽中，爬到鍋子的邊緣，\n跳到左邊的座位上，立刻\n衝到戶外，一邊哭泣一邊\n氣喘吁吁地逃回家，\n慶幸自己逃過一劫。\n回頭一看，\n原本以為只是一個人類，一個年輕人，\n沒想到竟然是奧基基里穆伊，像神一樣強大的人。\n我以為只是人類設置的弓箭陷阱，\n每天惡作劇，奧基基里穆伊\n非常生氣，想用艾草小弓箭\n殺死我，但我也\n並非只是身份低微的神，如果死得毫無意義，死得很難看，\n我的親人們也會感到困惑。\n他可憐我，\n所以，我逃跑時，他並沒有追趕。\n在那之前，兔子\n有鹿那麼大，\n因為我做了這樣的惡作劇，\n所以變成了奧基基里穆伊的一片肉那麼小。\n今後我們的同伴都會變成這麼小吧。\n今後的兔子們啊，千萬不要再惡作劇了！\n兔子首領這樣教導著孩子們，然後去世了。"
# }兔子親自吟唱的歌謠「桑帕亞 特雷克」
#
# 桑帕亞 特雷克
# 越過兩道山谷，越過三道山谷，
# 一邊玩耍，一邊跟隨著哥哥前往山裡。
# 每天都跟在哥哥身後，
# 看見人類設置了弓箭陷阱，哥哥便將弓箭
# 破壞掉。我總是嘲笑他，
# 以此為樂。這天又
# 去了，卻
# 出乎意料地，
# 哥哥被弓箭射中，哭喊著。
# 我嚇了一跳，飛奔到哥哥身邊，
# 哥哥哭著說道：
# 「弟弟啊，你現在
# 趕快跑回
# 我們村子的後方，
# 大聲呼喊——哥哥被弓箭射中了，呼喔呼喔伊！」
# 我聽了，
# 回答說：「好，好。」然後
# 越過兩道山谷，越過三道山谷，
# 一邊玩耍，一邊來到
# 我們村子的後方。
# 在那裡才想起哥哥派我來做什麼，
# 我正要大聲呼喊，
# 卻完全忘記了哥哥要我說什麼。
# 我呆立在那裡，
# 想要回想起來，卻怎麼也想不起來。
# 然後又
# 越過兩道山谷，越過三道山谷，
# 一邊倒退著跳躍，
# 回到哥哥所在的地方，
# 卻空無一人。
# 只留下哥哥的血跡。
# (到這裡故事轉向別處)
# 凱托卡 沃伊沃伊 凱托卡, 凱托卡 沃伊 凱托卡
# 每天我都去山裡，
# 破壞人類設置的弓箭陷阱，
# 並以此為樂。
# 有一天，我又來到之前的地方，發現那裡設置了弓箭陷阱，
# 而在那旁邊，設置了一個小小的艾草弓箭。
# 我看到那個，
# 心想：「這種東西，有什麼用呢？」
# 覺得很好笑，
# 就稍微碰了一下，正要逃跑，
# 卻出乎意料地
# 被那弓箭緊緊地
# 夾住了。
# 越是掙扎想要逃脫，
# 就夾得越緊，無計可施，
# 我哭泣著。
# 這時，有什麼東西
# 飛到我身邊，一看原來是我的弟弟。
# 我很高興，囑咐他將此事告知我們族人，
# 但等了許久，卻毫無音訊。
# 我哭泣著，這時
# 出現了一個身影。一看，
# 是一位像神一樣美麗的人類年輕人，
# 笑咪咪地，抓住我，
# 帶到某個地方。只見
# 一個巨大的房子裡，堆滿了神的寶物。
# 那位年輕人點燃了火，
# 將一個大鍋架在火上，拔出掛著的刀，
# 將我的身體連皮帶肉切成碎塊，
# 裝滿整個鍋子，然後將頭伸到鍋子底下，
# 開始點火燒煮。我想要
# 逃脫，便伺機尋找人類年輕人的破綻，
# 但人類年輕人卻寸步不離地盯著我。
# 「如果鍋子煮沸，我就被煮熟了，那樣就太沒意義了，死得很難看！」
# 我這樣想著，伺機尋找人類年輕人的疏忽，
# 好不容易
# 將自己變成一片肉，
# 混入升騰的蒸汽中，爬到鍋子的邊緣，
# 跳到左邊的座位上，立刻
# 衝到戶外，一邊哭泣一邊
# 氣喘吁吁地逃回家，
# 慶幸自己逃過一劫。
# 回頭一看，
# 原本以為只是一個人類，一個年輕人，
# 沒想到竟然是奧基基里穆伊，像神一樣強大的人。
# 我以為只是人類設置的弓箭陷阱，
# 每天惡作劇，奧基基里穆伊
# 非常生氣，想用艾草小弓箭
# 殺死我，但我也
# 並非只是身份低微的神，如果死得毫無意義，死得很難看，
# 我的親人們也會感到困惑。
# 他可憐我，
# 所以，我逃跑時，他並沒有追趕。
# 在那之前，兔子
# 有鹿那麼大，
# 因為我做了這樣的惡作劇，
# 所以變成了奧基基里穆伊的一片肉那麼小。
# 今後我們的同伴都會變成這麼小吧。
# 今後的兔子們啊，千萬不要再惡作劇了！
# 兔子首領這樣教導著孩子們，然後去世了。
# The original translation is generally accurate, but some phrases can be improved for better flow and cultural relevance in Chinese. Some terms are kept in Japanese (Okikirmui) which is good. Here's a breakdown:
#
# *   **桑帕亞 特雷克 (Sanpaya Tereke):** Keep as is.
# *   **弩 (Nu):** Accurate translation, but consider using a more descriptive term like "弓箭" (gong jian) for better understanding.
# *   **呼喔呼喔伊 (Hoo hoo i):** Keep as is, as it's a sound effect.
# *   **凱托卡 沃伊沃伊 凱托卡,凱托卡 沃伊 凱托卡 (Ketoka Woivoi Ketoka, Ketoka Woi Ketoka):** Keep as is.
# *   **奧基基里穆伊 (Okikirmui):** Keep as is.
#
# I will focus on improving the flow and naturalness of the Chinese while maintaining accuracy.
# {
#   "comment": "The original translation is generally accurate but can be improved in terms of flow, word choice, and capturing the nuances of the original Japanese text. Some phrases are a bit clunky and can be made more natural-sounding in Chinese. The use of more vivid and descriptive language can also enhance the storytelling aspect of the chant. Some terms like '間' needs to be clarified with context. The translation of names should be consistent.",
#   "updated_translation": "沼澤魔神親自吟唱的歌謠「哈利茲 昆納」\n\n哈利茲 昆納\n某個風和日麗的日子裡，\n我只露出眼睛和嘴巴，\n在我的沼澤地裡窺視。\n遠遠地，從海邊傳來人們的說話聲。\n看見兩個年輕人結伴走來。\n走在前面那個人，看來像個勇者，具備勇者的氣度，\n宛如神祇般俊美。\n但看走在後面那個人，面容憔悴，\n臉色也很差，一邊低聲商量著什麼一邊走來。\n經過我的沼澤地旁，\n正好來到我面前時，後面那個臉色難看的男人\n停下腳步，再停下腳步，捂住自己的鼻子，\n「啊，好臭！真討厭的沼澤地！經過這糟糕的沼澤地，\n真是骯髒，這究竟是什麼啊，這麼臭！」\n聽了這些話，我怒火中燒，簡直要忘了自己的存在。\n從泥沼中猛然跳了出來。我這一跳，\n地面裂開，大地崩塌。一邊發出獠牙的\n怒吼，一邊猛烈地追趕他們。\n走在前面的那個人，一見情況不妙，\n像魚兒般靈巧地轉身，從臉色難看的男人的\n腋下鑽了過去，飛也似地逃走了。\n我追趕那個青臉的男人兩三間（距離單位，約三到六米），\n立刻追上，一口從頭吞了下去。\n於是這次我用盡所有力氣追趕他，\n來到了人類的村莊，一個很大的村莊後面。\n看見從那邊\n走來一位火之老嫗，神之老嫗，身穿紅色的衣裳，六層衣裳\n繫緊腰帶，披著六層衣裳，\n拄著紅色的拐杖，朝我飛奔而來。\n「哎呀哎呀，你來我們愛努村\n做什麼？快回去，快回去！」\n一邊說著，一邊舉起紅色的拐杖，金色的拐杖敲打我，\n從拐杖中，火焰像\n雨點般傾瀉到我的身上。\n但是我一點也不在意，\n一邊發出獠牙的怒吼，一邊追趕那個男人。\n那個男人在村子裡\n像陀螺般四處逃竄。我緊追在後，\n大地裂開，大地崩塌。村子裡一片騷動，\n有人拉著妻子的手，有人拉著孩子的手，哭喊著\n四處逃竄，一片沸騰的景象。但是\n我一點也不在意，揚起漫天塵土。\n火之老女神跑到我的身邊，\n巨大的火焰，在我身上飛舞。\n在那混亂之中，那個男人跑進一間房子裡，\n立刻又跑了出來。\n看見他用蓬草做成的小弓，搭上蓬草做成的小箭，\n從那邊，笑嘻嘻地，瞄準著我。\n看到那樣，我覺得可笑。\n「那樣小小的蓬草箭，怎麼可能傷得了人呢？」\n一邊想著，我一邊發出獠牙的怒吼，\n想要一口從頭吞下去的時候，\n那時那個男人狠狠地射中了我的脖子。\n從那以後發生了什麼，我就完全不知道了。\n突然回過神來，發現\n我正處於一條巨大龍的兩隻耳朵之間。\n村裡的人們聚集起來，那個我追趕的年輕人\n大聲地指揮著，把我的屍體仔細地切成碎片，\n運到一處燒成灰燼，把那些灰燼\n丟棄到山岩的背後。\n現在我才明白，我原以為只是普通的人，\n只是個年輕人，\n其實是奧基基穆伊（Okikirmui），神之勇者。\n我是可怕的壞神，惡魔神，因為我靠近\n人類的村莊，\n奧基基穆伊為了保護村莊，故意激怒我，\n讓我追趕他，然後用蓬草箭殺了我。\n還有，之前我吞下去的\n青臉的男人，我以為是人類，\n其實是奧基基穆伊用自己的排泄物做成人形，\n把他帶來的。\n我是魔神，現在已經被\n地獄的可怕的壞地方帶走了。\n從今以後，人類的國家，不會再有任何危險，\n也不會有任何阻礙了吧。\n我是可怕的魔神，\n卻敗在一個人類的計謀之下，\n現在只能以無聊的死法，糟糕的死法死去。\n沼澤的魔神這樣講述著。"
# }沼澤魔神親自吟唱的歌謠「哈利茲 昆納」
#
# 哈利茲 昆納
# 某個風和日麗的日子裡，
# 我只露出眼睛和嘴巴，
# 在我的沼澤地裡窺視。
# 遠遠地，從海邊傳來人們的說話聲。
# 看見兩個年輕人結伴走來。
# 走在前面那個人，看來像個勇者，具備勇者的氣度，
# 宛如神祇般俊美。
# 但看走在後面那個人，面容憔悴，
# 臉色也很差，一邊低聲商量著什麼一邊走來。
# 經過我的沼澤地旁，
# 正好來到我面前時，後面那個臉色難看的男人
# 停下腳步，再停下腳步，捂住自己的鼻子，
# 「啊，好臭！真討厭的沼澤地！經過這糟糕的沼澤地，
# 真是骯髒，這究竟是什麼啊，這麼臭！」
# 聽了這些話，我怒火中燒，簡直要忘了自己的存在。
# 從泥沼中猛然跳了出來。我這一跳，
# 地面裂開，大地崩塌。一邊發出獠牙的
# 怒吼，一邊猛烈地追趕他們。
# 走在前面的那個人，一見情況不妙，
# 像魚兒般靈巧地轉身，從臉色難看的男人的
# 腋下鑽了過去，飛也似地逃走了。
# 我追趕那個青臉的男人兩三間（距離單位，約三到六米），
# 立刻追上，一口從頭吞了下去。
# 於是這次我用盡所有力氣追趕他，
# 來到了人類的村莊，一個很大的村莊後面。
# 看見從那邊
# 走來一位火之老嫗，神之老嫗，身穿紅色的衣裳，六層衣裳
# 繫緊腰帶，披著六層衣裳，
# 拄著紅色的拐杖，朝我飛奔而來。
# 「哎呀哎呀，你來我們愛努村
# 做什麼？快回去，快回去！」
# 一邊說著，一邊舉起紅色的拐杖，金色的拐杖敲打我，
# 從拐杖中，火焰像
# 雨點般傾瀉到我的身上。
# 但是我一點也不在意，
# 一邊發出獠牙的怒吼，一邊追趕那個男人。
# 那個男人在村子裡
# 像陀螺般四處逃竄。我緊追在後，
# 大地裂開，大地崩塌。村子裡一片騷動，
# 有人拉著妻子的手，有人拉著孩子的手，哭喊著
# 四處逃竄，一片沸騰的景象。但是
# 我一點也不在意，揚起漫天塵土。
# 火之老女神跑到我的身邊，
# 巨大的火焰，在我身上飛舞。
# 在那混亂之中，那個男人跑進一間房子裡，
# 立刻又跑了出來。
# 看見他用蓬草做成的小弓，搭上蓬草做成的小箭，
# 從那邊，笑嘻嘻地，瞄準著我。
# 看到那樣，我覺得可笑。
# 「那樣小小的蓬草箭，怎麼可能傷得了人呢？」
# 一邊想著，我一邊發出獠牙的怒吼，
# 想要一口從頭吞下去的時候，
# 那時那個男人狠狠地射中了我的脖子。
# 從那以後發生了什麼，我就完全不知道了。
# 突然回過神來，發現
# 我正處於一條巨大龍的兩隻耳朵之間。
# 村裡的人們聚集起來，那個我追趕的年輕人
# 大聲地指揮著，把我的屍體仔細地切成碎片，
# 運到一處燒成灰燼，把那些灰燼
# 丟棄到山岩的背後。
# 現在我才明白，我原以為只是普通的人，
# 只是個年輕人，
# 其實是奧基基穆伊（Okikirmui），神之勇者。
# 我是可怕的壞神，惡魔神，因為我靠近
# 人類的村莊，
# 奧基基穆伊為了保護村莊，故意激怒我，
# 讓我追趕他，然後用蓬草箭殺了我。
# 還有，之前我吞下去的
# 青臉的男人，我以為是人類，
# 其實是奧基基穆伊用自己的排泄物做成人形，
# 把他帶來的。
# 我是魔神，現在已經被
# 地獄的可怕的壞地方帶走了。
# 從今以後，人類的國家，不會再有任何危險，
# 也不會有任何阻礙了吧。
# 我是可怕的魔神，
# 卻敗在一個人類的計謀之下，
# 現在只能以無聊的死法，糟糕的死法死去。
# 沼澤的魔神這樣講述著。
# The original translation is generally accurate but can be improved in terms of flow, word choice, and capturing the nuances of the original Japanese text. Some phrases are a bit clunky and can be made more natural-sounding in Chinese. The use of more vivid and descriptive language can also enhance the storytelling aspect of the chant. Some terms like '間' needs to be clarified with context. The translation of names should be consistent.
# {
#   "comment": "The original translation is generally good, but some phrases can be improved for better flow and naturalness in Chinese. Some terms also need clarification or more accurate translation.\n\n*   **霍特瑙 (Hotenao):** Keep the original Japanese term as it's a proper noun and its meaning is unclear without further context.\n*   **小矮人:** While technically correct, consider using a more descriptive term like \"小童\" or \"小人\" to better capture the mythical nuance.\n*   **御幣之岬:** Keep the original Japanese term as it's a proper noun and its meaning is unclear without further context.\n*   **爐緣:** This is a very specific term. Consider adding a brief explanation in parentheses for clarity, like \"爐緣 (火爐邊框)\".\n*   **嗶嗶, 嗶咚, 嗶咚咚:** These are onomatopoeic sounds. Consider keeping them as is or finding similar-sounding onomatopoeia in Chinese that convey a similar feeling of annoyance or childishness. For now, I will keep them as is.\n*   The flow of some sentences can be improved to sound more natural in Chinese.",
#   "updated_translation": "小狼神親自吟唱的歌謠\n「霍特瑙」\n\n霍特瑙\n某天因為太過無聊，便到海邊去,\n玩耍時來了一個小童，\n我往河下游去，\n他也往河下游去，\n我往河上游去，他也往河上游去，擋住了我的去路。\n這樣往河下游六次，\n往河上游六次之後，小童\n終於按捺不住，面露怒色地說道：\n「嗶嗶\n你這小鬼，壞小鬼，要是你再這樣，\n就說說看這海岬，以前的名字和現在的名字。」\n我聽了，笑著說道：\n「誰會不知道這海岬以前的名字和\n現在的名字呢！\n以前，因為有尊貴偉大的神明和人類居住，\n所以這海岬被稱為神之岬，\n但現在時代衰退了，\n所以被叫做御幣之岬！」\n聽我這麼說，小童說道：\n「嗶咚，嗶咚\n你這小鬼，你真的這麼厲害，\n就說說看這條河以前的名字和現在的名字。」\n聽了，我說道：\n「誰會不知道這條河以前的名字和\n現在的名字呢！\n以前，在偉大的時代，這條河被稱為\n水流湍急的河，\n但現在世道衰退了，所以被叫做水流緩慢的河。」\n聽我這麼說，小童說道：\n「嗶咚咚，嗶咚咚\n你真的這麼厲害，\n那我們來互相揭露彼此的真面目吧。」\n聽了，我說道：\n「誰會不知道你的真面目呢！\n很久以前，奧基基穆伊去山上\n建造狩獵小屋時，用榛木做了爐緣(火爐邊框)，\n那爐緣被火烤得乾燥。\n奧基基穆伊一踩一邊，另一邊就\n翹起來，奧基基穆伊一怒之下\n就把那爐緣拿到河邊\n丟掉了。\n之後那爐緣就順著水流漂流，\n流到海裡，神明們看見它被遠方的海浪，近方的海浪\n拍打的樣子，\n覺得可敬偉大的奧基基穆伊親手製作的東西，竟然這樣\n毫無用處地迷失漂流，和海水一起腐爛，\n實在太可惜了，所以神明們\n就把那爐緣變成了魚，\n命名為爐緣魚。\n然而那爐緣魚，因為不知道自己的身分，\n所以變成人形四處遊蕩。\n那爐緣魚就是你。」\n聽我這麼說，小童臉色\n不斷變化，\n「嗶咚咚，嗶咚咚！\n你，是小小的，狼的孩子\n啊。」\n說完，立刻撲通一聲跳進海裡。\n我目送著他，只見一條紅色的魚\n擺動著尾鰭，一直往遠方\n游去。\n小狼神這樣講述著。"
# }小狼神親自吟唱的歌謠
# 「霍特瑙」
#
# 霍特瑙
# 某天因為太過無聊，便到海邊去,
# 玩耍時來了一個小童，
# 我往河下游去，
# 他也往河下游去，
# 我往河上游去，他也往河上游去，擋住了我的去路。
# 這樣往河下游六次，
# 往河上游六次之後，小童
# 終於按捺不住，面露怒色地說道：
# 「嗶嗶
# 你這小鬼，壞小鬼，要是你再這樣，
# 就說說看這海岬，以前的名字和現在的名字。」
# 我聽了，笑著說道：
# 「誰會不知道這海岬以前的名字和
# 現在的名字呢！
# 以前，因為有尊貴偉大的神明和人類居住，
# 所以這海岬被稱為神之岬，
# 但現在時代衰退了，
# 所以被叫做御幣之岬！」
# 聽我這麼說，小童說道：
# 「嗶咚，嗶咚
# 你這小鬼，你真的這麼厲害，
# 就說說看這條河以前的名字和現在的名字。」
# 聽了，我說道：
# 「誰會不知道這條河以前的名字和
# 現在的名字呢！
# 以前，在偉大的時代，這條河被稱為
# 水流湍急的河，
# 但現在世道衰退了，所以被叫做水流緩慢的河。」
# 聽我這麼說，小童說道：
# 「嗶咚咚，嗶咚咚
# 你真的這麼厲害，
# 那我們來互相揭露彼此的真面目吧。」
# 聽了，我說道：
# 「誰會不知道你的真面目呢！
# 很久以前，奧基基穆伊去山上
# 建造狩獵小屋時，用榛木做了爐緣(火爐邊框)，
# 那爐緣被火烤得乾燥。
# 奧基基穆伊一踩一邊，另一邊就
# 翹起來，奧基基穆伊一怒之下
# 就把那爐緣拿到河邊
# 丟掉了。
# 之後那爐緣就順著水流漂流，
# 流到海裡，神明們看見它被遠方的海浪，近方的海浪
# 拍打的樣子，
# 覺得可敬偉大的奧基基穆伊親手製作的東西，竟然這樣
# 毫無用處地迷失漂流，和海水一起腐爛，
# 實在太可惜了，所以神明們
# 就把那爐緣變成了魚，
# 命名為爐緣魚。
# 然而那爐緣魚，因為不知道自己的身分，
# 所以變成人形四處遊蕩。
# 那爐緣魚就是你。」
# 聽我這麼說，小童臉色
# 不斷變化，
# 「嗶咚咚，嗶咚咚！
# 你，是小小的，狼的孩子
# 啊。」
# 說完，立刻撲通一聲跳進海裡。
# 我目送著他，只見一條紅色的魚
# 擺動著尾鰭，一直往遠方
# 游去。
# 小狼神這樣講述著。
# The original translation is generally good, but some phrases can be improved for better flow and naturalness in Chinese. Some terms also need clarification or more accurate translation.
#
# *   **霍特瑙 (Hotenao):** Keep the original Japanese term as it's a proper noun and its meaning is unclear without further context.
# *   **小矮人:** While technically correct, consider using a more descriptive term like "小童" or "小人" to better capture the mythical nuance.
# *   **御幣之岬:** Keep the original Japanese term as it's a proper noun and its meaning is unclear without further context.
# *   **爐緣:** This is a very specific term. Consider adding a brief explanation in parentheses for clarity, like "爐緣 (火爐邊框)".
# *   **嗶嗶, 嗶咚, 嗶咚咚:** These are onomatopoeic sounds. Consider keeping them as is or finding similar-sounding onomatopoeia in Chinese that convey a similar feeling of annoyance or childishness. For now, I will keep them as is.
# *   The flow of some sentences can be improved to sound more natural in Chinese.
# {
#   "comment": "The original translation is generally accurate, but some areas can be improved for better flow and cultural nuance. Here's a breakdown:\n\n*   **孔庫瓦 (Konkuwa):** Keeping the original sound is good. No change needed.\n*   **Repetitive Phrases:** The phrase \"一邊敲打著鑲邊木桶(シントコ)的蓋子, 一邊說道\" is repeated many times. While accurate, it can be stylistically improved by varying the sentence structure or implying the action.\n*   **\"五個半的談判\":** This is literally \"five and a half negotiations\". It's crucial to understand the cultural context to translate this effectively. Without further context, I'll keep it literal but add a note about potential deeper meaning.\n*   **\"羽ぐるみ引っぱたいて殺してしまった\":** The translation \"連同羽毛一起狠狠地拍打, 將牠殺死了\" is accurate but a bit verbose. A more concise and impactful translation is possible.\n*   **\"川ガラス\":** Translated as 河烏鴉. While technically correct, 川ガラス might refer to a specific type of bird. Keeping the original name with a footnote explaining it might be better for accuracy.\n*   **\"新月代頭(武士髮型)\":** While accurate, it might be better to explain the cultural significance of this hairstyle in a footnote.\n*   **Overall Flow:** Some sentences are a bit long and could be broken down for better readability in Chinese.\n",
#   "updated_translation": "貓頭鷹神親自吟唱的歌謠\n**「孔庫瓦」**\n\n「孔庫瓦,\n往昔我說話之時,\n如纏繞櫻花樹皮的弓,\n弓把的中央鳴響般響亮。\n如今卻已衰老，年事已高。\n然而，若有誰雄辯滔滔，\n對使者之職充滿自信，\n我願委託他前往天國，\n進行五個半的談判。」* \n\n我敲打著鑲邊木桶(シントコ)的蓋子說道。\n這時，入口處傳來聲音：\n「捨我之外，誰還能擔當使者，\n既雄辯又充滿自信呢？」\n我一看，原來是隻年輕的烏鴉。\n我將牠請進屋內，為了派遣這隻年輕的烏鴉為使者，我詳細告知牠談判內容。\n三天過去，當我講述第三個談判要點時，卻發現這隻年輕的烏鴉在爐邊打瞌睡。\n我頓時怒火中燒，抓住這隻年輕的烏鴉，將牠連羽帶毛地狠狠拍打死了。\n\n然後，我又敲打著鑲邊木桶的蓋子說道：\n「若有誰對使者之職充滿自信，\n我願委託他前往天國，\n進行五個半的談判。」*\n\n這時，又有人在入口處說道：\n「捨我之外，誰還能如此雄辯，\n足以擔當前往天國的使者呢？」\n我一看，原來是隻山橿鳥。\n我將牠請進屋內，又講述五個半的談判內容。\n四天過去，當我講述第四個要點時，這隻山橿鳥卻在爐邊打瞌睡。\n我怒不可遏，抓住這隻山橿鳥，將牠連羽帶毛地狠狠拍打死了。\n\n然後，我又敲打著鑲邊木桶的蓋子說道：\n「若有誰雄辯滔滔，\n對使者之職充滿自信，\n我願委託他前往天國，\n進行五個半的談判。」*\n\n這時，有人以恭敬的態度走了進來，我一看，原來是隻川ガラス*的年輕鳥，牠儀表堂堂，坐在左側的位置。\n於是我敲打著鑲邊木桶的蓋子，不分晝夜地講述五個半的要點。\n只見這隻川ガラス，毫無疲態，專心聆聽，日夜不停。\n到了第六天，我剛一講完，牠立刻從天窗飛出，前往天國了。\n\n這次談判的大致內容是，人類世界正遭受饑荒，人們即將餓死。\n究其原因，原來是天國掌管鹿的神祇和掌管魚的神祇商議後決定，既不放出鹿，也不放出魚。\n無論人們如何祈求，他們都置之不理。\n因此，人們去山裡狩獵，卻找不到鹿；去河裡捕魚，也捕不到魚。\n我見此情景，怒火中燒，於是派遣使者前往鹿神和魚神那裡。\n\n過了幾天，空中傳來微弱的聲音，接著有人走了進來。\n我一看，原來是那隻川ガラス，如今牠比之前更加俊美，充滿了英勇的氣概，開始陳述回覆的談判內容。\n\n天國的鹿神和魚神至今不放出鹿和魚的原因是，人類在捕獲鹿時，用木頭敲擊鹿的頭部，剝下鹿皮後，就將鹿頭隨意丟棄在山林中；在捕獲魚時，用腐爛的木頭敲擊魚的頭部，將其殺死。\n鹿群赤身裸體，哭泣著回到鹿神的身邊；魚群則銜著腐爛的木頭，回到魚神的身邊。\n鹿神和魚神因此震怒，經過商議，決定不放出鹿和魚。\n但如果從今以後，人類能夠善待鹿和魚，那麼他們就會放出鹿和魚。鹿神和魚神是這麼說的。\n\n我聽完後，對這隻川ガラス讚不絕口。\n我發現，人類的確對待鹿和魚非常粗暴。\n從那以後，為了避免再次發生這種情況，我在人們睡夢中告誡他們。\n人類也意識到自己的錯誤，從此以後，像製作御幣(幣帛)一樣精美地製作捕魚工具，用它來捕魚。\n捕獲鹿時，也會將鹿頭裝飾得漂漂亮亮，進行祭祀。\n魚群因此感到高興，銜著美麗的御幣前往魚神的身邊；鹿群也高高興興地剃了新月代頭*，回到鹿神的身邊。\n鹿神和魚神對此感到非常高興，於是放出了大量的魚，放出了大量的鹿。\n人類從此以後，再也沒有任何困擾，過著衣食無憂的生活。\n我見此情景，感到非常安心。\n\n我已經年老體衰，本想前往天國，但由於我所守護的人類國家正遭受饑荒，人們即將餓死，我不能置之不理，所以一直留在此地。\n如今我已沒有任何牽掛，因此決定將最強壯、最年輕的勇者留在我的身後，讓他守護人類世界，而我今天就要前往天國了。\n\n就這樣，作為國家守護神的貓頭鷹翁神講述完畢，便前往天國了。\n\n*註：\n*「五個半的談判」: 此處的「五個半」可能具有更深層的文化或宗教含義，需要更多背景資訊才能準確翻譯。\n*「川ガラス」:  可能指日本特有的一種河烏鴉，具體種類需要進一步考證。\n*「新月代頭」:  武士髮型，代表著對神明的敬意。\n"
# }貓頭鷹神親自吟唱的歌謠
# **「孔庫瓦」**
#
# 「孔庫瓦,
# 往昔我說話之時,
# 如纏繞櫻花樹皮的弓,
# 弓把的中央鳴響般響亮。
# 如今卻已衰老，年事已高。
# 然而，若有誰雄辯滔滔，
# 對使者之職充滿自信，
# 我願委託他前往天國，
# 進行五個半的談判。」*
#
# 我敲打著鑲邊木桶(シントコ)的蓋子說道。
# 這時，入口處傳來聲音：
# 「捨我之外，誰還能擔當使者，
# 既雄辯又充滿自信呢？」
# 我一看，原來是隻年輕的烏鴉。
# 我將牠請進屋內，為了派遣這隻年輕的烏鴉為使者，我詳細告知牠談判內容。
# 三天過去，當我講述第三個談判要點時，卻發現這隻年輕的烏鴉在爐邊打瞌睡。
# 我頓時怒火中燒，抓住這隻年輕的烏鴉，將牠連羽帶毛地狠狠拍打死了。
#
# 然後，我又敲打著鑲邊木桶的蓋子說道：
# 「若有誰對使者之職充滿自信，
# 我願委託他前往天國，
# 進行五個半的談判。」*
#
# 這時，又有人在入口處說道：
# 「捨我之外，誰還能如此雄辯，
# 足以擔當前往天國的使者呢？」
# 我一看，原來是隻山橿鳥。
# 我將牠請進屋內，又講述五個半的談判內容。
# 四天過去，當我講述第四個要點時，這隻山橿鳥卻在爐邊打瞌睡。
# 我怒不可遏，抓住這隻山橿鳥，將牠連羽帶毛地狠狠拍打死了。
#
# 然後，我又敲打著鑲邊木桶的蓋子說道：
# 「若有誰雄辯滔滔，
# 對使者之職充滿自信，
# 我願委託他前往天國，
# 進行五個半的談判。」*
#
# 這時，有人以恭敬的態度走了進來，我一看，原來是隻川ガラス*的年輕鳥，牠儀表堂堂，坐在左側的位置。
# 於是我敲打著鑲邊木桶的蓋子，不分晝夜地講述五個半的要點。
# 只見這隻川ガラス，毫無疲態，專心聆聽，日夜不停。
# 到了第六天，我剛一講完，牠立刻從天窗飛出，前往天國了。
#
# 這次談判的大致內容是，人類世界正遭受饑荒，人們即將餓死。
# 究其原因，原來是天國掌管鹿的神祇和掌管魚的神祇商議後決定，既不放出鹿，也不放出魚。
# 無論人們如何祈求，他們都置之不理。
# 因此，人們去山裡狩獵，卻找不到鹿；去河裡捕魚，也捕不到魚。
# 我見此情景，怒火中燒，於是派遣使者前往鹿神和魚神那裡。
#
# 過了幾天，空中傳來微弱的聲音，接著有人走了進來。
# 我一看，原來是那隻川ガラス，如今牠比之前更加俊美，充滿了英勇的氣概，開始陳述回覆的談判內容。
#
# 天國的鹿神和魚神至今不放出鹿和魚的原因是，人類在捕獲鹿時，用木頭敲擊鹿的頭部，剝下鹿皮後，就將鹿頭隨意丟棄在山林中；在捕獲魚時，用腐爛的木頭敲擊魚的頭部，將其殺死。
# 鹿群赤身裸體，哭泣著回到鹿神的身邊；魚群則銜著腐爛的木頭，回到魚神的身邊。
# 鹿神和魚神因此震怒，經過商議，決定不放出鹿和魚。
# 但如果從今以後，人類能夠善待鹿和魚，那麼他們就會放出鹿和魚。鹿神和魚神是這麼說的。
#
# 我聽完後，對這隻川ガラス讚不絕口。
# 我發現，人類的確對待鹿和魚非常粗暴。
# 從那以後，為了避免再次發生這種情況，我在人們睡夢中告誡他們。
# 人類也意識到自己的錯誤，從此以後，像製作御幣(幣帛)一樣精美地製作捕魚工具，用它來捕魚。
# 捕獲鹿時，也會將鹿頭裝飾得漂漂亮亮，進行祭祀。
# 魚群因此感到高興，銜著美麗的御幣前往魚神的身邊；鹿群也高高興興地剃了新月代頭*，回到鹿神的身邊。
# 鹿神和魚神對此感到非常高興，於是放出了大量的魚，放出了大量的鹿。
# 人類從此以後，再也沒有任何困擾，過著衣食無憂的生活。
# 我見此情景，感到非常安心。
#
# 我已經年老體衰，本想前往天國，但由於我所守護的人類國家正遭受饑荒，人們即將餓死，我不能置之不理，所以一直留在此地。
# 如今我已沒有任何牽掛，因此決定將最強壯、最年輕的勇者留在我的身後，讓他守護人類世界，而我今天就要前往天國了。
#
# 就這樣，作為國家守護神的貓頭鷹翁神講述完畢，便前往天國了。
#
# *註：
# *「五個半的談判」: 此處的「五個半」可能具有更深層的文化或宗教含義，需要更多背景資訊才能準確翻譯。
# *「川ガラス」:  可能指日本特有的一種河烏鴉，具體種類需要進一步考證。
# *「新月代頭」:  武士髮型，代表著對神明的敬意。
#
# The original translation is generally accurate, but some areas can be improved for better flow and cultural nuance. Here's a breakdown:
#
# *   **孔庫瓦 (Konkuwa):** Keeping the original sound is good. No change needed.
# *   **Repetitive Phrases:** The phrase "一邊敲打著鑲邊木桶(シントコ)的蓋子, 一邊說道" is repeated many times. While accurate, it can be stylistically improved by varying the sentence structure or implying the action.
# *   **"五個半的談判":** This is literally "five and a half negotiations". It's crucial to understand the cultural context to translate this effectively. Without further context, I'll keep it literal but add a note about potential deeper meaning.
# *   **"羽ぐるみ引っぱたいて殺してしまった":** The translation "連同羽毛一起狠狠地拍打, 將牠殺死了" is accurate but a bit verbose. A more concise and impactful translation is possible.
# *   **"川ガラス":** Translated as 河烏鴉. While technically correct, 川ガラス might refer to a specific type of bird. Keeping the original name with a footnote explaining it might be better for accuracy.
# *   **"新月代頭(武士髮型)":** While accurate, it might be better to explain the cultural significance of this hairstyle in a footnote.
# *   **Overall Flow:** Some sentences are a bit long and could be broken down for better readability in Chinese.
#
# {
#   "comment": "The original translation is generally accurate but can be improved in terms of naturalness and cultural appropriateness for a Traditional Chinese audience. Some honorifics are overused, and certain phrases can be made more idiomatic. The translation also retains the Japanese term \"ごめ\", which should ideally be translated or explained. Some sentences are a bit too literal and could benefit from restructuring for better flow in Chinese. The consistent use of \"大人\" after each sibling title feels repetitive and unnatural in Chinese; it's better to imply respect through context and tone.",
#   "updated_translation": "海神親自吟唱的歌謠「アトイカ トマトマキ クントテアシ フム フム!」\n\nアトイカ トマトマキ クントテアシ フムフム\n長兄、六位兄長、長姊、六位姊姊，\n短兄、六位兄長、短姊、六位姊姊，\n養育著我。而我卻\n在堆滿寶物的地方搭建高床，於高床上\n坐著雕刻刀鞘，\n以此為\n事，度過每一天。\n每天早上，兄長們\n背著箭筒與姊姊們一同出門，\n傍晚時分，帶著疲憊的神色\n空手而歸。姊姊們\n明明也很疲憊，卻還是準備餐點，為我擺上膳食，\n自己也用餐，餐後收拾完畢，\n之後，兄長們便忙著製作箭矢。\n箭筒裝滿後，大家都累了，\n睡覺時便發出高亢的鼾聲。\n隔天，天還沒亮，\n大家就起身，姊姊們準備餐點，為我擺上膳食，\n大家用完餐後，又背起箭筒\n出門去了。傍晚時分，又\n帶著疲憊的神色空手而歸，\n姊姊們準備餐點，兄長們製作箭矢，\n日復一日，做著相同的事情。\n\n某天，兄長們和姊姊們又\n背著箭筒出門去了。\n我原本在雕刻寶物，不久後\n便從高床上起身，拿著金製小弓和\n金製小箭走到外面，\n看見大海遼闊平靜，\n鯨魚們在海的東邊和西邊\n嬉戲玩耍。接著，\n海的東邊，長姊和六位姊姊手牽著手圍成一圈，\n短姊和六位姊姊，將鯨魚趕入圈中，\n長兄和六位兄長、短兄和六位兄長\n瞄準圈中的鯨魚射箭，箭矢\n從鯨魚下方穿過，從上方掠過。\n他們每天都做著這樣的事情。看見海的中央，\n一隻巨大的鯨魚和牠的孩子鯨魚正在上下\n嬉戲玩耍，\n我便從遠處用金製小弓\n搭上金製小箭瞄準射去，一箭\n同時貫穿了母子鯨魚。\n於是，我將其中一隻鯨魚從中間斬斷，\n將一半拋入姊姊們的圈中。然後，將一隻半的鯨魚\n放在尾巴下方，朝著人類的國度\n前進，抵達オタシュツ村，\n將一隻半的鯨魚\n推到村子的海灘上。\n\n之後，我悠閒地在海上\n游了回去，\n這時，有人\n氣喘吁吁地從旁邊跑過，\n一看，原來是海のごめ(海神使者)。\n牠氣喘吁吁地說道：\n「トミンカリクル カムイカリクル イソヤンケクル\n勇猛的神明、偉大的神明，\n您為何要將如此豐盛的海產賜給卑賤的人類、邪惡的人類呢？\n卑賤的人類、邪惡的人類，用斧頭\n用鐮刀將豐盛的海產切得亂七八糟，又戳又\n削，勇猛的神明，\n偉大的神明，請快點將豐盛的海產\n收回去吧。賜給他們這麼多海產，\n卑賤的人類、邪惡的人類卻\n不心懷感激，還做出這種事。」\n聽了牠的話，我笑著說：\n「我既然已經賜給人類了，\n現在就是他們的東西了，人類\n要用鐮刀戳，還是用斧頭\n削，都隨他們的便，讓他們自由地吃就好，\n那又怎麼樣呢？」\n海のごめ雖然有些不知所措，\n我卻毫不在意，悠閒地在海上\n游著，\n在快要日落的時候，抵達了我的海域。看見\n十二位兄長、十二位\n姊姊，因為搬不動那半隻鯨魚，\n大家一起大聲呼喊著，\n在海的東邊，慢吞吞地搬運著。\n我實在是感到無語。\n\n我沒有理會他們，直接回家，\n坐在高床上。\n於是我回頭看向人類的世界，\n看見我推上去的那一隻\n半的鯨魚周圍，聚集了許多出色的男人和\n出色的女人，盛裝打扮，\n歡欣鼓舞地慶祝海產，後方的沙丘\n上鋪著華麗的墊子，\nオタシュツ村的村長\n穿著六件和服，束著腰帶，披著六件和服，\n頭戴華麗的神之冠、祖先之冠，\n腰佩神授之劍，\n以如神般美麗的姿態高舉雙手\n禮拜著。人類們哭著\n喜悅著海產。\n雖然海のごめ說人類們\n用斧頭和鐮刀戳著我推上去的鯨魚，\n但村長和\n村民們，從以前就\n將寶物中最珍貴的神劍取出，\n用它來切割肉並搬運著。\n而且，我的兄長們和姊姊們也沒有回來的\n跡象。\n\n過了兩三天，窗戶邊\n好像有什麼東西，\n於是我回頭看去，看見窗戶上\n放著裝滿\n酒的金盃，上面\n放著裝飾著御幣的酒箸，\n來回移動著，以使者的身分陳述道：\n「我們是オタシュツ村的人，\n雖然非常惶恐，但還是要獻上御神酒。」\nオタシュツ村的村長代表\n全體村民向我表達感謝之意，\n詳細地說明了事情的經過，\n「トミンカリクル カムイカリクル イソヤンケクル\n若非偉大的神明、勇猛的神明，還有誰\n會在我們村子發生饑荒，\n已經到了走投無路的地步，\n食物匱乏的時候，憐憫我們呢？\n您賜給我們村子生命，\n實在非常感謝，我們用海產釀造了\n少許的酒，並附上小小的幣束，\n向大神表達謝意。」\n裝飾著御幣的酒箸來回移動著陳述道。\n\n於是我起身，將金盃\n拿起，恭敬地接過，\n打開上方座位的六個酒桶的蓋子，\n將美酒一點一點地倒入，\n將金盃放在窗戶上。\n做完這些後，我便坐在高床上，\n看見那金盃連同酒箸\n都消失了。之後，我繼續雕刻刀鞘，\n雕刻著，不知不覺地\n抬頭一看，\n家裡已經擺滿了美麗的幣束，\n家裡瀰漫著白色的雲霧，白色的閃電\n閃爍著。我覺得啊，真美。\n\n之後，又過了兩三天，\n這時，終於聽見家裡外面，兄長們和\n姊姊們大聲呼喊著，\n拉著那隻鯨魚回來了。我感到無語。\n我望著他們進入家裡的樣子，\n兄長們和姊姊們\n非常疲憊，臉色也憔悴不堪。\n大家都進來後，看見這麼多的幣束，\n驚訝地拜了又拜。\n不久，東邊座位的六個酒桶\n都滿溢了出來，神明喜愛的\n酒香瀰漫在屋內。\n\n之後，我用美麗的幣束裝飾家裡，\n邀請遠方的神明、附近的神明，\n舉辦盛大的酒宴。姊姊們\n煮了鯨魚，獻給神明們，\n神明們都讚不絕口，非常高興。\n宴會正酣時，我起身，\n詳細地說明了人類世界發生饑荒，\n我憐憫他們，將海產推上去的經過，\n以及我善待人類，卻被邪惡的神明\n嫉妒，海のごめ中傷我的事情，\n還有オタシュツ村的\n村長以如此這般的言語向我表達感謝，\n裝飾著幣束的酒箸成為使者前來的事情等等，\n神明們聽了，\n一致點頭，\n稱讚我。\n\n之後，又舉辦了盛大的宴會，\n神明們在那裡\n跳舞的聲音、躍動的聲音，\n發出美妙的聲響，姊姊們\n拿著提壺在席間斟酒，\n也有人與女神們\n一同用美妙的聲音歌唱。\n過了兩三天，宴會結束了。\n我將兩三個美麗的幣束\n獻給神明們，神明們都彎著腰\n恭敬地行了無數次的禮，\n大家都回到自己的家裡。\n\n在那之後，無論何時都一樣，長兄、六位兄長，\n長姊、六位姊姊，短姊、六位姊姊，\n短兄、六位兄長都一起，\n只要人類們釀酒，每次都會\n送酒給我，並將幣束送到我這裡。\n現在，人類們也不再為食物不足所\n困擾，過著平穩的\n生活，我感到很安心。"
# }海神親自吟唱的歌謠「アトイカ トマトマキ クントテアシ フム フム!」
#
# アトイカ トマトマキ クントテアシ フムフム
# 長兄、六位兄長、長姊、六位姊姊，
# 短兄、六位兄長、短姊、六位姊姊，
# 養育著我。而我卻
# 在堆滿寶物的地方搭建高床，於高床上
# 坐著雕刻刀鞘，
# 以此為
# 事，度過每一天。
# 每天早上，兄長們
# 背著箭筒與姊姊們一同出門，
# 傍晚時分，帶著疲憊的神色
# 空手而歸。姊姊們
# 明明也很疲憊，卻還是準備餐點，為我擺上膳食，
# 自己也用餐，餐後收拾完畢，
# 之後，兄長們便忙著製作箭矢。
# 箭筒裝滿後，大家都累了，
# 睡覺時便發出高亢的鼾聲。
# 隔天，天還沒亮，
# 大家就起身，姊姊們準備餐點，為我擺上膳食，
# 大家用完餐後，又背起箭筒
# 出門去了。傍晚時分，又
# 帶著疲憊的神色空手而歸，
# 姊姊們準備餐點，兄長們製作箭矢，
# 日復一日，做著相同的事情。
#
# 某天，兄長們和姊姊們又
# 背著箭筒出門去了。
# 我原本在雕刻寶物，不久後
# 便從高床上起身，拿著金製小弓和
# 金製小箭走到外面，
# 看見大海遼闊平靜，
# 鯨魚們在海的東邊和西邊
# 嬉戲玩耍。接著，
# 海的東邊，長姊和六位姊姊手牽著手圍成一圈，
# 短姊和六位姊姊，將鯨魚趕入圈中，
# 長兄和六位兄長、短兄和六位兄長
# 瞄準圈中的鯨魚射箭，箭矢
# 從鯨魚下方穿過，從上方掠過。
# 他們每天都做著這樣的事情。看見海的中央，
# 一隻巨大的鯨魚和牠的孩子鯨魚正在上下
# 嬉戲玩耍，
# 我便從遠處用金製小弓
# 搭上金製小箭瞄準射去，一箭
# 同時貫穿了母子鯨魚。
# 於是，我將其中一隻鯨魚從中間斬斷，
# 將一半拋入姊姊們的圈中。然後，將一隻半的鯨魚
# 放在尾巴下方，朝著人類的國度
# 前進，抵達オタシュツ村，
# 將一隻半的鯨魚
# 推到村子的海灘上。
#
# 之後，我悠閒地在海上
# 游了回去，
# 這時，有人
# 氣喘吁吁地從旁邊跑過，
# 一看，原來是海のごめ(海神使者)。
# 牠氣喘吁吁地說道：
# 「トミンカリクル カムイカリクル イソヤンケクル
# 勇猛的神明、偉大的神明，
# 您為何要將如此豐盛的海產賜給卑賤的人類、邪惡的人類呢？
# 卑賤的人類、邪惡的人類，用斧頭
# 用鐮刀將豐盛的海產切得亂七八糟，又戳又
# 削，勇猛的神明，
# 偉大的神明，請快點將豐盛的海產
# 收回去吧。賜給他們這麼多海產，
# 卑賤的人類、邪惡的人類卻
# 不心懷感激，還做出這種事。」
# 聽了牠的話，我笑著說：
# 「我既然已經賜給人類了，
# 現在就是他們的東西了，人類
# 要用鐮刀戳，還是用斧頭
# 削，都隨他們的便，讓他們自由地吃就好，
# 那又怎麼樣呢？」
# 海のごめ雖然有些不知所措，
# 我卻毫不在意，悠閒地在海上
# 游著，
# 在快要日落的時候，抵達了我的海域。看見
# 十二位兄長、十二位
# 姊姊，因為搬不動那半隻鯨魚，
# 大家一起大聲呼喊著，
# 在海的東邊，慢吞吞地搬運著。
# 我實在是感到無語。
#
# 我沒有理會他們，直接回家，
# 坐在高床上。
# 於是我回頭看向人類的世界，
# 看見我推上去的那一隻
# 半的鯨魚周圍，聚集了許多出色的男人和
# 出色的女人，盛裝打扮，
# 歡欣鼓舞地慶祝海產，後方的沙丘
# 上鋪著華麗的墊子，
# オタシュツ村的村長
# 穿著六件和服，束著腰帶，披著六件和服，
# 頭戴華麗的神之冠、祖先之冠，
# 腰佩神授之劍，
# 以如神般美麗的姿態高舉雙手
# 禮拜著。人類們哭著
# 喜悅著海產。
# 雖然海のごめ說人類們
# 用斧頭和鐮刀戳著我推上去的鯨魚，
# 但村長和
# 村民們，從以前就
# 將寶物中最珍貴的神劍取出，
# 用它來切割肉並搬運著。
# 而且，我的兄長們和姊姊們也沒有回來的
# 跡象。
#
# 過了兩三天，窗戶邊
# 好像有什麼東西，
# 於是我回頭看去，看見窗戶上
# 放著裝滿
# 酒的金盃，上面
# 放著裝飾著御幣的酒箸，
# 來回移動著，以使者的身分陳述道：
# 「我們是オタシュツ村的人，
# 雖然非常惶恐，但還是要獻上御神酒。」
# オタシュツ村的村長代表
# 全體村民向我表達感謝之意，
# 詳細地說明了事情的經過，
# 「トミンカリクル カムイカリクル イソヤンケクル
# 若非偉大的神明、勇猛的神明，還有誰
# 會在我們村子發生饑荒，
# 已經到了走投無路的地步，
# 食物匱乏的時候，憐憫我們呢？
# 您賜給我們村子生命，
# 實在非常感謝，我們用海產釀造了
# 少許的酒，並附上小小的幣束，
# 向大神表達謝意。」
# 裝飾著御幣的酒箸來回移動著陳述道。
#
# 於是我起身，將金盃
# 拿起，恭敬地接過，
# 打開上方座位的六個酒桶的蓋子，
# 將美酒一點一點地倒入，
# 將金盃放在窗戶上。
# 做完這些後，我便坐在高床上，
# 看見那金盃連同酒箸
# 都消失了。之後，我繼續雕刻刀鞘，
# 雕刻著，不知不覺地
# 抬頭一看，
# 家裡已經擺滿了美麗的幣束，
# 家裡瀰漫著白色的雲霧，白色的閃電
# 閃爍著。我覺得啊，真美。
#
# 之後，又過了兩三天，
# 這時，終於聽見家裡外面，兄長們和
# 姊姊們大聲呼喊著，
# 拉著那隻鯨魚回來了。我感到無語。
# 我望著他們進入家裡的樣子，
# 兄長們和姊姊們
# 非常疲憊，臉色也憔悴不堪。
# 大家都進來後，看見這麼多的幣束，
# 驚訝地拜了又拜。
# 不久，東邊座位的六個酒桶
# 都滿溢了出來，神明喜愛的
# 酒香瀰漫在屋內。
#
# 之後，我用美麗的幣束裝飾家裡，
# 邀請遠方的神明、附近的神明，
# 舉辦盛大的酒宴。姊姊們
# 煮了鯨魚，獻給神明們，
# 神明們都讚不絕口，非常高興。
# 宴會正酣時，我起身，
# 詳細地說明了人類世界發生饑荒，
# 我憐憫他們，將海產推上去的經過，
# 以及我善待人類，卻被邪惡的神明
# 嫉妒，海のごめ中傷我的事情，
# 還有オタシュツ村的
# 村長以如此這般的言語向我表達感謝，
# 裝飾著幣束的酒箸成為使者前來的事情等等，
# 神明們聽了，
# 一致點頭，
# 稱讚我。
#
# 之後，又舉辦了盛大的宴會，
# 神明們在那裡
# 跳舞的聲音、躍動的聲音，
# 發出美妙的聲響，姊姊們
# 拿著提壺在席間斟酒，
# 也有人與女神們
# 一同用美妙的聲音歌唱。
# 過了兩三天，宴會結束了。
# 我將兩三個美麗的幣束
# 獻給神明們，神明們都彎著腰
# 恭敬地行了無數次的禮，
# 大家都回到自己的家裡。
#
# 在那之後，無論何時都一樣，長兄、六位兄長，
# 長姊、六位姊姊，短姊、六位姊姊，
# 短兄、六位兄長都一起，
# 只要人類們釀酒，每次都會
# 送酒給我，並將幣束送到我這裡。
# 現在，人類們也不再為食物不足所
# 困擾，過著平穩的
# 生活，我感到很安心。
# The original translation is generally accurate but can be improved in terms of naturalness and cultural appropriateness for a Traditional Chinese audience. Some honorifics are overused, and certain phrases can be made more idiomatic. The translation also retains the Japanese term "ごめ", which should ideally be translated or explained. Some sentences are a bit too literal and could benefit from restructuring for better flow in Chinese. The consistent use of "大人" after each sibling title feels repetitive and unnatural in Chinese; it's better to imply respect through context and tone.
# {
#   "comment": "The original translation is mostly accurate, but some phrases can be improved for better flow and naturalness in Chinese. Specifically, I will focus on refining the descriptive parts and making the dialogue more vivid. Also, I will keep the original language for untranslatable terms.",
#   "updated_translation": "青蛙自歌的謠曲\n「托羅羅 漢羅庫 漢羅庫!」\n\n托羅羅 漢羅庫 漢羅庫!\n「有一天，在草原上四處跳躍\n玩耍時，我看到\n一間房舍，便走到門前\n想一探究竟，屋內堆滿了寶物，旁邊\n有個高台。在那高台上\n有個年輕人正埋首刻著刀鞘，\n我心生惡作劇，便坐在門檻上\n鳴叫「托羅羅 漢羅庫 漢羅庫!」\n沒想到，那年輕人抬起握刀的手\n望向我，微微一笑，\n「那是你的歌謠嗎？是你的喜悅之歌嗎？\n真想再多聽幾遍呢。」於是我\n得意地鳴叫「托羅羅 漢羅庫 漢羅庫!」\n那年輕人接著說道，\n「那是你的ユーカラ嗎？薩凱豪嗎？\n還想更靠近一點聽呢。」\n我聽了心花怒放，便跳到下座的\n爐緣上\n鳴叫「托羅羅 漢羅庫 漢羅庫!」\n那年輕人又說道，\n「那是你的ユーカラ嗎？薩凱豪嗎？\n還想更靠近一點聽呢。」聽到這話，我\n更是樂不可支，便跳到上座爐緣的\n角落\n鳴叫「托羅羅 漢羅庫 漢羅庫!」\n突然！那年輕人猛地站起身\n彷彿跳起來一般，抓起一根巨大的燃燒木柴\n朝我狠狠地扔了過來，只覺得\n眼前一黑，之後\n發生了什麼便全然不知了。\n再次醒來時，我發現\n自己身處垃圾堆的盡頭，一隻肚子鼓脹的青蛙\n已經死去，而我正坐在牠的兩耳之間。\n仔細一看，我原以為\n只是一戶普通人家，沒想到竟是オキキリムイ，如神一般\n強大之人的住所，而且\n我竟然在不知那是オキキリムイ的情況下，就\n冒失地惡作劇了。\n我如今就要這樣無謂地死去，悲慘地死去\n所以，從今往後的\n青蛙們啊，千萬別再對人類惡作劇了啊。\n」\n肚子鼓脹的青蛙這樣說著，便斷了氣。"
# }青蛙自歌的謠曲
# 「托羅羅 漢羅庫 漢羅庫!」
#
# 托羅羅 漢羅庫 漢羅庫!
# 「有一天，在草原上四處跳躍
# 玩耍時，我看到
# 一間房舍，便走到門前
# 想一探究竟，屋內堆滿了寶物，旁邊
# 有個高台。在那高台上
# 有個年輕人正埋首刻著刀鞘，
# 我心生惡作劇，便坐在門檻上
# 鳴叫「托羅羅 漢羅庫 漢羅庫!」
# 沒想到，那年輕人抬起握刀的手
# 望向我，微微一笑，
# 「那是你的歌謠嗎？是你的喜悅之歌嗎？
# 真想再多聽幾遍呢。」於是我
# 得意地鳴叫「托羅羅 漢羅庫 漢羅庫!」
# 那年輕人接著說道，
# 「那是你的ユーカラ嗎？薩凱豪嗎？
# 還想更靠近一點聽呢。」
# 我聽了心花怒放，便跳到下座的
# 爐緣上
# 鳴叫「托羅羅 漢羅庫 漢羅庫!」
# 那年輕人又說道，
# 「那是你的ユーカラ嗎？薩凱豪嗎？
# 還想更靠近一點聽呢。」聽到這話，我
# 更是樂不可支，便跳到上座爐緣的
# 角落
# 鳴叫「托羅羅 漢羅庫 漢羅庫!」
# 突然！那年輕人猛地站起身
# 彷彿跳起來一般，抓起一根巨大的燃燒木柴
# 朝我狠狠地扔了過來，只覺得
# 眼前一黑，之後
# 發生了什麼便全然不知了。
# 再次醒來時，我發現
# 自己身處垃圾堆的盡頭，一隻肚子鼓脹的青蛙
# 已經死去，而我正坐在牠的兩耳之間。
# 仔細一看，我原以為
# 只是一戶普通人家，沒想到竟是オキキリムイ，如神一般
# 強大之人的住所，而且
# 我竟然在不知那是オキキリムイ的情況下，就
# 冒失地惡作劇了。
# 我如今就要這樣無謂地死去，悲慘地死去
# 所以，從今往後的
# 青蛙們啊，千萬別再對人類惡作劇了啊。
# 」
# 肚子鼓脹的青蛙這樣說著，便斷了氣。
# The original translation is mostly accurate, but some phrases can be improved for better flow and naturalness in Chinese. Specifically, I will focus on refining the descriptive parts and making the dialogue more vivid. Also, I will keep the original language for untranslatable terms.
# {
#   "comment": "The current translation is generally good, but some areas can be improved for accuracy and naturalness in Chinese. Specifically, the transliteration of \"小オキキリムイ\" can be refined, and the description of the salmon's reaction to the water can be made more vivid. The phrase \"腰の央\" can be translated more precisely. Also, the flow of some sentences can be adjusted for better readability in Chinese.",
#   "updated_translation": "小奧奇基利穆伊自己唱的歌謠\n「クツニサ クトンクトン」\n\nクツニサ クトンクトン\n有一天，我到水源地去玩。\n出發後，在水源地看到一個小矮人，\n為了建造胡桃木的魚梁，正在彎著腰打樁。\n他看到我，就說：\n「你是誰？我的姪子啊，幫我一下。」\n我看見，因為是胡桃木的魚梁，\n所以流過來的是胡桃水，混濁不清。\n鮭魚們想要往上游，卻因為厭惡胡桃水的味道，\n哭哭啼啼地回去了。我非常生氣，\n一把搶過小矮人手中的打樁槌，\n朝他腰椎正中央敲去，\n我敲下去的聲音「砰」地響起。小矮人的\n腰椎被打斷，我便殺了他，\n把他踹進地獄。搖動他的胡桃木樁，\n看起來好像延伸到六層地獄的彼端。\n然後，我用盡腰部和全身的力量，\n從根本上折斷了那根木樁，把他踹進地獄。\n從水源地流出清新的風、清澈的水，\n原本哭著回去的鮭魚們，因為清新的風和清澈的水\n恢復了精神，牠們非常熱鬧，歡快地嬉戲，\n一邊拍打著水面，一邊往上游。我看到那樣，就安心了，\n沿著水流回家了。\n小奧奇基利穆伊這樣講述著。"
# }小奧奇基利穆伊自己唱的歌謠
# 「クツニサ クトンクトン」
#
# クツニサ クトンクトン
# 有一天，我到水源地去玩。
# 出發後，在水源地看到一個小矮人，
# 為了建造胡桃木的魚梁，正在彎著腰打樁。
# 他看到我，就說：
# 「你是誰？我的姪子啊，幫我一下。」
# 我看見，因為是胡桃木的魚梁，
# 所以流過來的是胡桃水，混濁不清。
# 鮭魚們想要往上游，卻因為厭惡胡桃水的味道，
# 哭哭啼啼地回去了。我非常生氣，
# 一把搶過小矮人手中的打樁槌，
# 朝他腰椎正中央敲去，
# 我敲下去的聲音「砰」地響起。小矮人的
# 腰椎被打斷，我便殺了他，
# 把他踹進地獄。搖動他的胡桃木樁，
# 看起來好像延伸到六層地獄的彼端。
# 然後，我用盡腰部和全身的力量，
# 從根本上折斷了那根木樁，把他踹進地獄。
# 從水源地流出清新的風、清澈的水，
# 原本哭著回去的鮭魚們，因為清新的風和清澈的水
# 恢復了精神，牠們非常熱鬧，歡快地嬉戲，
# 一邊拍打著水面，一邊往上游。我看到那樣，就安心了，
# 沿著水流回家了。
# 小奧奇基利穆伊這樣講述著。
# The current translation is generally good, but some areas can be improved for accuracy and naturalness in Chinese. Specifically, the transliteration of "小オキキリムイ" can be refined, and the description of the salmon's reaction to the water can be made more vivid. The phrase "腰の央" can be translated more precisely. Also, the flow of some sentences can be adjusted for better readability in Chinese.
# {
#   "comment": "The original translation is mostly accurate but can be improved in terms of naturalness and cultural relevance. Some phrases are too literal and sound awkward in Chinese. Also, some terms can be refined to better reflect the original Japanese nuance. For example, \"斷根\" is a bit too strong, and can be replaced with something milder. The use of \"囂張\" is also not the best fit. The repetition of \"另外\" can be avoided. Overall, the translation needs polishing to sound more like a traditional Chinese narrative.",
#   "updated_translation": "小オキキリム伊親自吟唱的歌謠\n「這砂，紅紅的」\n\n〔這砂，紅紅的〕\n某日，我溯溪遊玩，\n遇到了惡魔之子。\n無論何時，惡魔之子都容貌俊美，\n面若桃花，身穿黑衣，\n手持胡桃小弓，胡桃小箭。\n看到我，便笑嘻嘻地\n說道：\n「小オキキリム伊，一起玩吧！\n我這就讓魚兒絕跡給你看！」\n說著，便將胡桃小弓，胡桃小箭\n搭好，朝水源方向射去。\n水源流出胡桃水，混濁不堪，\n鮭魚們逆流而上，\n因厭惡胡桃水，哭泣著\n掉頭游走。惡魔之子\n見狀，笑嘻嘻。\n我看了，頓生怒意，\n便將我持有的銀色小弓，銀色小箭\n搭好，朝水源射去。\n水源流出銀色水，清澈見底，\n哭泣著離去的\n鮭魚們在清澈的水中恢復了活力，\n歡笑着嬉戲，\n啪嚓啪嚓地游了上去。\n於是，惡魔之子\n將天生的焦躁\n顯露在臉上，\n「你若真要如此，我就讓鹿群絕跡給你看！」說著，\n便將胡桃小弓，胡桃小箭搭好，\n朝天空射去。山的樹林中\n吹來胡桃風，捲起旋風，\n從山的樹林中，公鹿成群，\n母鹿也成群，被風吹起，\n整齊地升向天空。\n惡魔之子笑嘻嘻。\n我看了，怒火中燒，\n便將銀色小弓，銀色小箭\n搭好，朝鹿群射去。\n從天上，吹下銀色風，清澈的和風，\n公鹿成群，\n母鹿也成群，\n被吹回山的樹林之上。\n於是，惡魔之子\n將天生的焦躁顯露在臉上，\n「好大的膽子！\n你若真要做這種事，我們來比力氣吧！」\n說著，便脫下上衣。\n我也只剩一件薄衣，\n便扭打在一起。他也抱住我。從那之後，\n互相壓制，互相摔跤，\n但惡魔之子的力氣之大，\n令我吃驚。可是，最終，在某個時刻，\n我使出腰力，渾身解數，\n將惡魔之子\n扛到肩上，\n將他摔到山岩上，發出\n轟然巨響。殺了他，踩入地獄之後，一片寂靜。\n事情結束後，我沿著溪流回家，\n河裡，鮭魚們的笑聲，\n嬉鬧聲，喧囂地傳來，\n啪嚓啪嚓地聽得見。山的樹林中，\n公鹿們，母鹿們的笑聲，\n嬉鬧聲，充滿四處，\n在那裡，在這裡\n吃著東西。我看了，\n感到安心，回到\n我的家。\n小オキキリム伊如此說道。"
# }小オキキリム伊親自吟唱的歌謠
# 「這砂，紅紅的」
#
# 〔這砂，紅紅的〕
# 某日，我溯溪遊玩，
# 遇到了惡魔之子。
# 無論何時，惡魔之子都容貌俊美，
# 面若桃花，身穿黑衣，
# 手持胡桃小弓，胡桃小箭。
# 看到我，便笑嘻嘻地
# 說道：
# 「小オキキリム伊，一起玩吧！
# 我這就讓魚兒絕跡給你看！」
# 說著，便將胡桃小弓，胡桃小箭
# 搭好，朝水源方向射去。
# 水源流出胡桃水，混濁不堪，
# 鮭魚們逆流而上，
# 因厭惡胡桃水，哭泣著
# 掉頭游走。惡魔之子
# 見狀，笑嘻嘻。
# 我看了，頓生怒意，
# 便將我持有的銀色小弓，銀色小箭
# 搭好，朝水源射去。
# 水源流出銀色水，清澈見底，
# 哭泣著離去的
# 鮭魚們在清澈的水中恢復了活力，
# 歡笑着嬉戲，
# 啪嚓啪嚓地游了上去。
# 於是，惡魔之子
# 將天生的焦躁
# 顯露在臉上，
# 「你若真要如此，我就讓鹿群絕跡給你看！」說著，
# 便將胡桃小弓，胡桃小箭搭好，
# 朝天空射去。山的樹林中
# 吹來胡桃風，捲起旋風，
# 從山的樹林中，公鹿成群，
# 母鹿也成群，被風吹起，
# 整齊地升向天空。
# 惡魔之子笑嘻嘻。
# 我看了，怒火中燒，
# 便將銀色小弓，銀色小箭
# 搭好，朝鹿群射去。
# 從天上，吹下銀色風，清澈的和風，
# 公鹿成群，
# 母鹿也成群，
# 被吹回山的樹林之上。
# 於是，惡魔之子
# 將天生的焦躁顯露在臉上，
# 「好大的膽子！
# 你若真要做這種事，我們來比力氣吧！」
# 說著，便脫下上衣。
# 我也只剩一件薄衣，
# 便扭打在一起。他也抱住我。從那之後，
# 互相壓制，互相摔跤，
# 但惡魔之子的力氣之大，
# 令我吃驚。可是，最終，在某個時刻，
# 我使出腰力，渾身解數，
# 將惡魔之子
# 扛到肩上，
# 將他摔到山岩上，發出
# 轟然巨響。殺了他，踩入地獄之後，一片寂靜。
# 事情結束後，我沿著溪流回家，
# 河裡，鮭魚們的笑聲，
# 嬉鬧聲，喧囂地傳來，
# 啪嚓啪嚓地聽得見。山的樹林中，
# 公鹿們，母鹿們的笑聲，
# 嬉鬧聲，充滿四處，
# 在那裡，在這裡
# 吃著東西。我看了，
# 感到安心，回到
# 我的家。
# 小オキキリム伊如此說道。
# The original translation is mostly accurate but can be improved in terms of naturalness and cultural relevance. Some phrases are too literal and sound awkward in Chinese. Also, some terms can be refined to better reflect the original Japanese nuance. For example, "斷根" is a bit too strong, and can be replaced with something milder. The use of "囂張" is also not the best fit. The repetition of "另外" can be avoided. Overall, the translation needs polishing to sound more like a traditional Chinese narrative.
# {
#   "comment": "The original translation is generally good, but some phrases can be improved for better flow and accuracy. Specifically, I will focus on refining the descriptions of the girls' beauty, the otter's actions, and the overall narrative to enhance the storytelling in Chinese.\n\n1.  \"像神一般美麗\" (like a god, beautiful) can be more elegantly expressed.\n2.  The repetition of actions can be streamlined for better readability.\n3.  The ending can be slightly adjusted to emphasize the moral of the story.",
#   "updated_translation": "水獺自唱的歌謠\n「河童 咧嗚咧嗚 河童」\n\n河童 咧嗚咧嗚 河童\n有一天，我沿著河流嬉戲，\n游到薩瑪雲庫魯的\n汲水處時，\n看見薩瑪雲庫魯的妹妹，宛如女神般美麗動人，\n一手提著水桶，一手\n拿著香蒲束走來，\n我便只露出頭在河邊，\n問道：「妳有父親嗎？\n妳有母親嗎？」\n那女孩嚇了一跳，眼睛四處張望，\n發現了我，臉上頓時\n露出憤怒的表情，\n說：「啊，可惡的扁頭，壞扁頭\n竟敢愚弄人。狗兒們，上啊......」\n話音未落，大狗們就\n衝了過來，對著我齜牙咧嘴。\n我嚇了一跳，趕緊潛入河底，\n直接沿著河底逃走了。\n然後，我又在奧基基里穆伊的汲水處\n只露出頭來，\n看見奧基基里穆伊的妹妹，\n同樣有著女神般的美麗容貌，一手提著水桶，\n一手拿著香蒲束走來，\n我就問她：\n「妳有父親嗎？\n妳有母親嗎？」\n那女孩嚇了一跳，眼睛四處張望，\n發現了我，臉上頓時\n露出憤怒的表情，\n說：「啊，可惡的扁頭，壞扁頭\n竟敢愚弄人。狗兒們，上啊......」\n話音未落，大狗們就衝了過來。\n我看到這情景，想起剛才的事，\n覺得好笑，正想潛入河底\n逃走，\n沒想到狗兒們竟然會做出那種事，\n牠們齜牙咧嘴地\n跳入河底，撲向我，\n把我拖到岸上，我的頭和身體\n都被牠們撕咬，最後\n發生了什麼事，我就不知道了。\n突然回過神來，\n發現自己正坐在\n一隻大水獺的兩隻耳朵之間。\n我知道薩瑪雲庫魯和奧基基里穆伊\n都是沒有父母的，\n我還如此惡作劇，才會受到懲罰，\n被奧基基里穆伊的狗兒們殺死，\n落得如此可悲的下場。 \n今後的水獺們啊，切記不可再惡作劇了。\n水獺這樣講述著。"
# }水獺自唱的歌謠
# 「河童 咧嗚咧嗚 河童」
#
# 河童 咧嗚咧嗚 河童
# 有一天，我沿著河流嬉戲，
# 游到薩瑪雲庫魯的
# 汲水處時，
# 看見薩瑪雲庫魯的妹妹，宛如女神般美麗動人，
# 一手提著水桶，一手
# 拿著香蒲束走來，
# 我便只露出頭在河邊，
# 問道：「妳有父親嗎？
# 妳有母親嗎？」
# 那女孩嚇了一跳，眼睛四處張望，
# 發現了我，臉上頓時
# 露出憤怒的表情，
# 說：「啊，可惡的扁頭，壞扁頭
# 竟敢愚弄人。狗兒們，上啊......」
# 話音未落，大狗們就
# 衝了過來，對著我齜牙咧嘴。
# 我嚇了一跳，趕緊潛入河底，
# 直接沿著河底逃走了。
# 然後，我又在奧基基里穆伊的汲水處
# 只露出頭來，
# 看見奧基基里穆伊的妹妹，
# 同樣有著女神般的美麗容貌，一手提著水桶，
# 一手拿著香蒲束走來，
# 我就問她：
# 「妳有父親嗎？
# 妳有母親嗎？」
# 那女孩嚇了一跳，眼睛四處張望，
# 發現了我，臉上頓時
# 露出憤怒的表情，
# 說：「啊，可惡的扁頭，壞扁頭
# 竟敢愚弄人。狗兒們，上啊......」
# 話音未落，大狗們就衝了過來。
# 我看到這情景，想起剛才的事，
# 覺得好笑，正想潛入河底
# 逃走，
# 沒想到狗兒們竟然會做出那種事，
# 牠們齜牙咧嘴地
# 跳入河底，撲向我，
# 把我拖到岸上，我的頭和身體
# 都被牠們撕咬，最後
# 發生了什麼事，我就不知道了。
# 突然回過神來，
# 發現自己正坐在
# 一隻大水獺的兩隻耳朵之間。
# 我知道薩瑪雲庫魯和奧基基里穆伊
# 都是沒有父母的，
# 我還如此惡作劇，才會受到懲罰，
# 被奧基基里穆伊的狗兒們殺死，
# 落得如此可悲的下場。
# 今後的水獺們啊，切記不可再惡作劇了。
# 水獺這樣講述著。
# The original translation is generally good, but some phrases can be improved for better flow and accuracy. Specifically, I will focus on refining the descriptions of the girls' beauty, the otter's actions, and the overall narrative to enhance the storytelling in Chinese.
#
# 1.  "像神一般美麗" (like a god, beautiful) can be more elegantly expressed.
# 2.  The repetition of actions can be streamlined for better readability.
# 3.  The ending can be slightly adjusted to emphasize the moral of the story.
# {
#   "comment": "The original translation is generally good, but some phrases can be improved to be more natural and vivid in Chinese. Also, some terms can be refined for better cultural context and readability. Specifically:\n\n*   \"強烈的日光照射,我的棲身之處也乾涸了,我快要死了。\" can be more concise and impactful.\n*   The repetition of \"哭喊著\" can be varied for better flow.\n*   \"神一般美麗高貴\" can be enhanced to better convey the divine quality.\n*   \"蕗葉\" can be checked for a more accurate and culturally relevant translation.\n*   The descriptions of the sisters' actions regarding the粟米田 can be made more vivid.\n*   The final sentence can be slightly adjusted for a more natural concluding tone.",
#   "updated_translation": "沼貝自唱的歌謠「托努佩卡 蘭蘭」\n\n托努佩卡 蘭蘭\n烈日當空，我的居所也乾涸殆盡，奄奄一息。\n「誰能給我一口水，\n救救我吧！水啊，水啊！」我們哀號著，\n遠方海灘走來一位女子，\n背著竹簍。\n我們哭泣，她從我們身旁經過，\n看見我們，\n說：「可笑的沼貝，可憎的沼貝，哭哭啼啼，\n吵鬧喧嘩！」\n她踐踏我們，用腳尖踢開，連同貝殼一同踩碎，\n揚長而去，往山裡去了。\n「好痛，好苦，水啊，水啊！」我們哀嚎，\n遠方海灘又走來一位女子，\n背著竹簍。我們\n「誰能給我們一口水，救救我們吧！\n好痛，好苦，水啊，水啊！」呼喊。\n於是，那位姑娘，宛如神祇般美麗莊嚴，\n來到我們身邊，看見我們，\n說：「真是可憐，天氣如此炎熱，沼貝們的\n棲身之所都乾裂了，渴望著水，\n這是怎麼回事呢？\n似乎是被踐踏過了……」\n她一邊說著，一邊將我們一一撿起，\n放在蜂斗菜葉上，放入清澈的湖水中。\n我們暢飲清冽的湖水，頓時恢復了元氣，\n變得非常強壯。於是，我們開始\n探究這些女子的性情，\n發現先前到來，踐踏我們的\n可憎女子，惡毒的女人，是薩瑪雲庫爾的\n妹妹；而憐憫我們，\n幫助我們的年輕姑娘，溫柔嫻靜的\n是奧基基里穆伊的妹妹。\n薩瑪雲庫爾的妹妹心術不正，\n使得她的粟米田枯萎凋零；而奧基基里穆伊的\n妹妹的粟米田則結滿了豐碩的果實。\n那一年，奧基基里穆伊的妹妹迎來了大豐收。\n她明白這是因為我的緣故，\n便用沼貝的殼來收割粟米的穗。\n從那以後，每年，人類的女子們\n在收割粟米穗的時候，都會使用沼貝的殼。\n一隻沼貝如此訴說著。"
# }沼貝自唱的歌謠「托努佩卡 蘭蘭」
#
# 托努佩卡 蘭蘭
# 烈日當空，我的居所也乾涸殆盡，奄奄一息。
# 「誰能給我一口水，
# 救救我吧！水啊，水啊！」我們哀號著，
# 遠方海灘走來一位女子，
# 背著竹簍。
# 我們哭泣，她從我們身旁經過，
# 看見我們，
# 說：「可笑的沼貝，可憎的沼貝，哭哭啼啼，
# 吵鬧喧嘩！」
# 她踐踏我們，用腳尖踢開，連同貝殼一同踩碎，
# 揚長而去，往山裡去了。
# 「好痛，好苦，水啊，水啊！」我們哀嚎，
# 遠方海灘又走來一位女子，
# 背著竹簍。我們
# 「誰能給我們一口水，救救我們吧！
# 好痛，好苦，水啊，水啊！」呼喊。
# 於是，那位姑娘，宛如神祇般美麗莊嚴，
# 來到我們身邊，看見我們，
# 說：「真是可憐，天氣如此炎熱，沼貝們的
# 棲身之所都乾裂了，渴望著水，
# 這是怎麼回事呢？
# 似乎是被踐踏過了……」
# 她一邊說著，一邊將我們一一撿起，
# 放在蜂斗菜葉上，放入清澈的湖水中。
# 我們暢飲清冽的湖水，頓時恢復了元氣，
# 變得非常強壯。於是，我們開始
# 探究這些女子的性情，
# 發現先前到來，踐踏我們的
# 可憎女子，惡毒的女人，是薩瑪雲庫爾的
# 妹妹；而憐憫我們，
# 幫助我們的年輕姑娘，溫柔嫻靜的
# 是奧基基里穆伊的妹妹。
# 薩瑪雲庫爾的妹妹心術不正，
# 使得她的粟米田枯萎凋零；而奧基基里穆伊的
# 妹妹的粟米田則結滿了豐碩的果實。
# 那一年，奧基基里穆伊的妹妹迎來了大豐收。
# 她明白這是因為我的緣故，
# 便用沼貝的殼來收割粟米的穗。
# 從那以後，每年，人類的女子們
# 在收割粟米穗的時候，都會使用沼貝的殼。
# 一隻沼貝如此訴說著。
# The original translation is generally good, but some phrases can be improved to be more natural and vivid in Chinese. Also, some terms can be refined for better cultural context and readability. Specifically:
#
# *   "強烈的日光照射,我的棲身之處也乾涸了,我快要死了。" can be more concise and impactful.
# *   The repetition of "哭喊著" can be varied for better flow.
# *   "神一般美麗高貴" can be enhanced to better convey the divine quality.
# *   "蕗葉" can be checked for a more accurate and culturally relevant translation.
# *   The descriptions of the sisters' actions regarding the粟米田 can be made more vivid.
# *   The final sentence can be slightly adjusted for a more natural concluding tone.
